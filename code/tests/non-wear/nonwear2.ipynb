# %%
import pandas as pd
import os
import requests
import sys
from io import StringIO
from datetime import datetime, timedelta


'''
This script is designed to create a sleep log file for the group analysis of accelerometer data.
It reads the individual participant files by first matching labID with studyID, then builds path to individual files on the RDSS
Aggregates the sleep data by participant and session (with _accel suffix) and saves it to a CSV file.
'''

token = 'DE4E2DB72778DACA9B8848574107D2F5'
INT_DIR = '/mnt/lss/Projects/BOOST/InterventionStudy/3-experiment/data/act-int-test'
OBS_DIR = '/mnt/lss/Projects/BOOST/ObservationalStudy/3-experiment/data/act-obs-test'
rdss_dir = '/mnt/rdss/VossLab/Repositories/Accelerometer_Data/WearTime'

def compare_ids(rdss_dir, token, daysago=350):
    """
    Pulls all files from RDSS
    Pulls the list from RedCap
    Compares IDs and returns a dictionary with two keys:
        - 'matches': normal matches mapping boost_id to a list of dicts (filename, labID, date)
        - 'duplicates': a list of dictionaries each with lab_id, boost_id, filenames (list), and dates (list)
    """
    # Retrieve the RedCap report and duplicates from report
    report, report_duplicates = _return_report(token)
    # Retrieve the full RDSS file list and duplicate files merged with duplicates from report
    rdss, file_duplicates = _rdss_file_list(report_duplicates)

    # Initialize the result dictionary for normal (non-duplicate) matches
    result = {}

    # Iterate over the rows in the cleaned RedCap report
    for _, row in report.iterrows():
        boost_id = str(row['boost_id'])
        lab_id = str(row['lab_id'])
        
        # Find matching files in the RDSS list
        rdss_matches = rdss[rdss['ID'] == lab_id]
        if not rdss_matches.empty:
            if boost_id not in result:
                result[boost_id] = []
            for _, match_row in rdss_matches.iterrows():
                result[boost_id].append({
                    'filename': match_row['filename'],
                    'labID': lab_id,
                    'date': match_row['Date']
                })
    
    # Process duplicates into the desired structure.
    duplicates_dict = []
    if not file_duplicates.empty:
        # Group by lab_id and boost_id; each group represents one duplicate combination.
        grouped = file_duplicates.groupby(['lab_id', 'boost_id'])
        for (lab_id, boost_id), group in grouped:
            duplicates_dict.append({
                'lab_id': lab_id,
                'boost_id': boost_id,
                'filenames': group['filename'].tolist(),
                'dates': group['Date'].tolist()
            })
    else:
        print("Found no duplicates.")

    return {'matches': result, 'duplicates': duplicates_dict}

def _return_report(token):
    """
    pulls the id report from the rdss via redcap api.
    reads the report as a dataframe.
    checks for boost_ids that are associated with multiple lab_ids, logs a critical error,
    and removes these rows from the dataframe.
    separates duplicate rows (based on any column) from the cleaned data.
    
    returns:
        df_cleaned: dataframe with duplicates removed and problematic boost_ids excluded
        duplicate_rows: dataframe of duplicate rows
    """
    url = 'https://redcap.icts.uiowa.edu/redcap/api/'
    data = {
        'token': token,
        'content': 'report',
        'report_id': 43327,
        'format': 'csv'
    }
    r = requests.post(url, data=data)
    if r.status_code != 200:
        print(f"error! status code is {r.status_code}")
        sys.exit(1)
    
    df = pd.read_csv(StringIO(r.text))
    
    # identify boost_ids associated with multiple lab_ids.
    boost_id_counts = df.groupby('boost_id')['lab_id'].nunique()
    problematic_boost_ids = boost_id_counts[boost_id_counts > 1].index.tolist()
    
    if problematic_boost_ids:
        print(f"found boost_id(s) with multiple lab_ids: {', '.join(map(str, problematic_boost_ids))}. "
                        "these entries will be removed from processing.")
        df = df[~df['boost_id'].isin(problematic_boost_ids)]
    
    # identify and separate duplicate rows based on any column.
    duplicate_rows = df[df.duplicated(keep=False)]
    df_cleaned = df.drop_duplicates(keep=False)
    
    if not duplicate_rows.empty:
        print(f"duplicate rows found:\n{duplicate_rows}")
    
    return df_cleaned, duplicate_rows

def _rdss_file_list(duplicates, daysago=None):
    """
    extracts the first string before the space and the date from filenames ending with .csv
    in the specified folder and stores them in a dataframe.
    
    Also, merges the file list with duplicate report entries based on lab_id.
    
    Returns:
        df: DataFrame of all file entries
        merged_df: DataFrame of file entries that match duplicate lab_ids from the report
    """
    extracted_data = []

    # Loop through all files in the rdss_dir folder.
    for filename in os.listdir(rdss_dir):
        if filename.endswith('.csv'):
            try:
                # Handle both old and new filename formats
                if '_' in filename and filename.endswith('.csv'):
                    # New format: 1288_4-26-2025_Sleep.csv
                    parts = filename.replace('.csv', '').split('_')
                    if len(parts) >= 3:
                        base_name = parts[0]  # lab_id
                        date_part = parts[1]  # date
                        extracted_data.append({'ID': base_name, 'Date': date_part, 'filename': filename})
                    else:
                        print(f"Skipping file with unexpected format: {filename}")
                else:
                    try:
                        base_name = filename.split(' ')[0]  # Extract lab_id (old format)
                        date_part = filename.split('(')[1].split(')')[0]  # Extract date (old format)
                        extracted_data.append({'ID': base_name, 'Date': date_part, 'filename': filename})
                    except IndexError:
                        print(f"Skipping file with unexpected format: {filename}")
            except IndexError:
                print(f"Skipping file with unexpected format: {filename}")

    df = pd.DataFrame(extracted_data)

    if not df.empty:
        df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

        if daysago:
            cutoff_date = datetime.today() - timedelta(days=daysago)
            df = df[df['Date'] >= cutoff_date]  # Filter files within the last `daysago` days
        else:
            df = df[df['Date'] >= '2024-08-05']  # Filter out rows before the threshold date

    # Filter the file list to only include rows where ID is in the duplicate report (if any)
    if not duplicates.empty:
        matched_df = df[df['ID'].isin(duplicates['lab_id'])]
        # Merge with the duplicates to bring in boost_id information from the report
        merged_df = matched_df.merge(duplicates, left_on='ID', right_on='lab_id')
    else:
        merged_df = pd.DataFrame()

    return df, merged_df

matches = compare_ids(rdss_dir, token, daysago=None)
# Print the matches and duplicates for verification
print("Matches:")
for boost_id, files in matches['matches'].items():
    print(f"Boost ID: {boost_id}")
    for file_info in files:
        print(f"  - {file_info['filename']} (Lab ID: {file_info['labID']}, Date: {file_info['date']})")
print("\nDuplicates:")
for dup in matches['duplicates']:
    print(f"Lab ID: {dup['lab_id']}, Boost ID: {dup['boost_id']}")
    print(f"  Filenames: {', '.join(dup['filenames'])}")
    print(f"  Dates: {', '.join(map(str, dup['dates']))}")
# The above code is a complete script that compares IDs from RDSS and RedCap, identifies matches and duplicates, and prints the results.

'''
Below we create the sessions, where if the same subject ID has multiple files, we will create a session for each file ordered by date.
this will now be stored as a dataframe with the columns:
    # 'subject_id', 'session_id', 'filename', 'date'
    # where subject_id is 'sub-<subject_id>', session_id is 'ses-<session_number>', filename is the file name with full path, and date is the date of the file.
'''
def create_sessions(matches):
    """
    Create sessions from the matches dictionary.
    
    Args:
        matches (dict): Dictionary containing matches with boost_id as keys and list of file info as values.
    
    Returns:
        pd.DataFrame: DataFrame with columns 'subject_id', 'session_id', 'filename', 'date'.
    """
    sessions = []
    
    for boost_id, files in matches['matches'].items():
        subject_id = f'sub-{boost_id}'
        for i, file_info in enumerate(files):
            session_id = f'ses-{i + 1}'  # Session number starts from 1
            sessions.append({
                'subject_id': subject_id,
                'session_id': session_id,
                'filename': os.path.join(rdss_dir, file_info['filename']),
                'date': file_info['date']
            })
    
    return pd.DataFrame(sessions)

# Create sessions from the Matches
sessions_df = create_sessions(matches)
# Print the sessions DataFrame for verification
print("\nSessions DataFrame:")
print(sessions_df)
# Out:
# found boost_id(s) with multiple lab_ids: 7023. these entries will be removed from processing.
# Skipping file with unexpected format: 498_WearTime.csv
# Skipping file with unexpected format: 633_WearTime.csv
# Skipping file with unexpected format: 619_WearTime.csv
# Skipping file with unexpected format: 92_WearTime.csv
# Skipping file with unexpected format: 555_WearTime.csv
# Skipping file with unexpected format: 649_WearTime.csv
# Skipping file with unexpected format: 557_WearTime.csv
# Skipping file with unexpected format: 504_WearTime.csv
# Skipping file with unexpected format: 207_WearTime.csv
# Skipping file with unexpected format: AP_WearTime.csv
# Skipping file with unexpected format: 648_WearTime.csv
# Skipping file with unexpected format: 589_WearTime.csv
# Skipping file with unexpected format: 505_WearTime.csv
# Skipping file with unexpected format: 579_WearTime.csv
# Skipping file with unexpected format: 634_WearTime.csv
# Skipping file with unexpected format: 500_WearTime.csv
# Skipping file with unexpected format: 553_WearTime.csv
# Skipping file with unexpected format: KS_WearTime.csv
# Skipping file with unexpected format: 552_WearTime.csv
# Skipping file with unexpected format: 666_WearTime.csv
# Skipping file with unexpected format: 635_WearTime.csv
# Skipping file with unexpected format: 311_WearTime.csv
# Skipping file with unexpected format: 503_WearTime.csv
# Skipping file with unexpected format: 200_WearTime.csv
# Skipping file with unexpected format: 529_WearTime.csv
# Skipping file with unexpected format: 664_WearTime.csv
# Skipping file with unexpected format: 201_WearTime.csv
# Skipping file with unexpected format: 523_WearTime.csv
# Skipping file with unexpected format: 585_WearTime.csv
# Skipping file with unexpected format: 644_WearTime.csv
# Skipping file with unexpected format: 509_WearTime.csv
# Skipping file with unexpected format: 645_WearTime.csv
# Skipping file with unexpected format: 508_WearTime.csv
# Skipping file with unexpected format: 616_WearTime.csv
# Skipping file with unexpected format: 68_WearTime.csv
# Skipping file with unexpected format: 522_WearTime.csv
# Skipping file with unexpected format: 571_WearTime.csv
# Skipping file with unexpected format: 614_WearTime.csv
# Skipping file with unexpected format: 573_WearTime.csv
# Skipping file with unexpected format: 615_WearTime.csv
# Skipping file with unexpected format: 669_WearTime.csv
# Skipping file with unexpected format: 577_WearTime.csv
# Skipping file with unexpected format: 643_WearTime.csv
# Skipping file with unexpected format: 582_WearTime.csv
# Skipping file with unexpected format: 44_WearTime.csv
# Skipping file with unexpected format: 583_WearTime.csv
# Skipping file with unexpected format: 642_WearTime.csv
# Skipping file with unexpected format: 45_WearTime.csv
# Skipping file with unexpected format: 576_WearTime.csv
# Skipping file with unexpected format: 613_WearTime.csv
# Skipping file with unexpected format: 640_WearTime.csv
# Skipping file with unexpected format: 574_WearTime.csv
# Skipping file with unexpected format: 527_WearTime.csv
# Skipping file with unexpected format: 575_WearTime.csv
# Skipping file with unexpected format: 526_WearTime.csv
# Skipping file with unexpected format: 638_WearTime.csv
# Skipping file with unexpected format: 650_WearTime.csv
# Skipping file with unexpected format: 537_WearTime.csv
# Skipping file with unexpected format: 629_WearTime.csv
# Skipping file with unexpected format: 234_WearTime.csv
# Skipping file with unexpected format: 565_WearTime.csv
# Skipping file with unexpected format: 628_WearTime.csv
# Skipping file with unexpected format: 536_WearTime.csv
# Skipping file with unexpected format: 590_WearTime.csv
# Skipping file with unexpected format: 534_WearTime.csv
# Skipping file with unexpected format: 567_WearTime.csv
# Skipping file with unexpected format: 600_WearTime.csv
# Skipping file with unexpected format: 593_WearTime.csv
# Skipping file with unexpected format: 601_WearTime.csv
# Skipping file with unexpected format: 566_WearTime.csv
# Skipping file with unexpected format: 604_WearTime.csv
# Skipping file with unexpected format: 596_WearTime.csv
# Skipping file with unexpected format: 549_WearTime.csv
# Skipping file with unexpected format: DK_WearTime.csv
# Skipping file with unexpected format: 605_WearTime.csv
# Skipping file with unexpected format: 656_WearTime.csv
# Skipping file with unexpected format: 597_WearTime.csv
# Skipping file with unexpected format: RC1day_WearTime.csv
# Skipping file with unexpected format: 533_WearTime.csv
# Skipping file with unexpected format: 560_WearTime.csv
# Skipping file with unexpected format: 157_WearTime.csv
# Skipping file with unexpected format: 519_WearTime.csv
# Skipping file with unexpected format: 607_WearTime.csv
# Skipping file with unexpected format: 655_WearTime.csv
# Skipping file with unexpected format: 594_WearTime.csv
# Skipping file with unexpected format: 472_WearTime.csv
# Skipping file with unexpected format: 540_WearTime.csv
# Skipping file with unexpected format: 182_WearTime.csv
# Skipping file with unexpected format: 627_WearTime.csv
# Skipping file with unexpected format: 626_WearTime.csv
# Skipping file with unexpected format: 538_WearTime.csv
# Skipping file with unexpected format: 541_WearTime.csv
# Skipping file with unexpected format: 58_WearTime.csv
# Skipping file with unexpected format: 512_WearTime.csv
# Skipping file with unexpected format: 87_WearTime.csv
# Skipping file with unexpected format: 624_WearTime.csv
# Skipping file with unexpected format: 542_WearTime.csv
# Skipping file with unexpected format: 625_WearTime.csv
# Skipping file with unexpected format: 598_WearTime.csv
# Skipping file with unexpected format: 547_WearTime.csv
# Skipping file with unexpected format: 659_WearTime.csv
# Skipping file with unexpected format: 217_WearTime.csv
# Skipping file with unexpected format: 620_WearTime.csv
# Skipping file with unexpected format: 621_WearTime.csv
# Skipping file with unexpected format: 658_WearTime.csv
# Skipping file with unexpected format: 599_WearTime.csv
# Skipping file with unexpected format: 517_WearTime.csv
# Skipping file with unexpected format: 609_WearTime.csv
# Skipping file with unexpected format: 608_WearTime.csv
# Skipping file with unexpected format: 516_WearTime.csv
# Skipping file with unexpected format: 622_WearTime.csv
# Skipping file with unexpected format: 661_WearTime.csv
# Skipping file with unexpected format: 675_WearTime.csv
# Skipping file with unexpected format: 671_WearTime.csv
# Skipping file with unexpected format: 673_WearTime.csv
# Skipping file with unexpected format: 676_WearTime.csv
# Skipping file with unexpected format: 674_WearTime.csv
# Skipping file with unexpected format: 670_WearTime.csv
# Skipping file with unexpected format: 680_WearTime.csv
# Skipping file with unexpected format: 687_WearTime.csv
# Skipping file with unexpected format: 684_WearTime.csv
# Skipping file with unexpected format: 683_WearTime.csv
# Skipping file with unexpected format: 677_WearTime.csv
# Skipping file with unexpected format: 691_WearTime.csv
# Skipping file with unexpected format: 686_WearTime.csv
# Skipping file with unexpected format: 694_WearTime.csv
# Skipping file with unexpected format: 667_WearTime.csv
# Skipping file with unexpected format: 695_WearTime.csv
# Skipping file with unexpected format: 690_WearTime.csv
# Skipping file with unexpected format: 678_WearTime.csv
# Skipping file with unexpected format: 706_WearTime.csv
# Skipping file with unexpected format: 525_WearTime.csv
# Skipping file with unexpected format: 702_WearTime.csv
# Skipping file with unexpected format: 700_WearTime.csv
# Skipping file with unexpected format: 510_WearTime.csv
# Skipping file with unexpected format: 720_WearTime.csv
# Skipping file with unexpected format: 715_WearTime.csv
# Skipping file with unexpected format: 717_WearTime.csv
# Skipping file with unexpected format: 707_WearTime.csv
# Skipping file with unexpected format: 697_WearTime.csv
# Skipping file with unexpected format: 710_WearTime.csv
# Skipping file with unexpected format: 709_WearTime.csv
# Skipping file with unexpected format: 689_WearTime.csv
# Skipping file with unexpected format: 721_WearTime.csv
# Skipping file with unexpected format: 728_WearTime.csv
# Skipping file with unexpected format: 723_WearTime.csv
# Skipping file with unexpected format: 708_WearTime.csv
# Skipping file with unexpected format: 714_WearTime.csv
# Skipping file with unexpected format: 722_WearTime.csv
# Skipping file with unexpected format: 727_WearTime.csv
# Skipping file with unexpected format: 730_WearTime.csv
# Skipping file with unexpected format: 487_WearTime.csv
# Skipping file with unexpected format: 731_WearTime.csv
# Skipping file with unexpected format: 699_WearTime.csv
# Skipping file with unexpected format: 725_WearTime.csv
# Skipping file with unexpected format: 713_WearTime.csv
# Skipping file with unexpected format: 729_WearTime.csv
# Skipping file with unexpected format: 52_WearTime.csv
# Skipping file with unexpected format: 261_WearTime.csv
# Skipping file with unexpected format: 734_WearTime.csv
# Skipping file with unexpected format: 736_WearTime.csv
# Skipping file with unexpected format: 733_WearTime.csv
# Skipping file with unexpected format: 738_WearTime.csv
# Skipping file with unexpected format: 741_WearTime.csv
# Skipping file with unexpected format: 197_WearTime.csv
# Skipping file with unexpected format: 581_WearTime.csv
# Skipping file with unexpected format: 71_WearTime.csv
# Skipping file with unexpected format: 176_WearTime.csv
# Skipping file with unexpected format: 750_WearTime.csv
# Skipping file with unexpected format: 753_WearTime.csv
# Skipping file with unexpected format: 757_WearTime.csv
# Skipping file with unexpected format: 758_WearTime.csv
# Skipping file with unexpected format: 763_WearTime.csv
# Skipping file with unexpected format: 759_WearTime.csv
# Skipping file with unexpected format: 760_WearTime.csv
# Skipping file with unexpected format: 764_WearTime.csv
# Skipping file with unexpected format: 507_WearTime.csv
# Skipping file with unexpected format: 766_WearTime.csv
# Skipping file with unexpected format: 769_WearTime.csv
# Skipping file with unexpected format: 770_WearTime.csv
# Skipping file with unexpected format: 767_WearTime.csv
# Skipping file with unexpected format: 774_WearTime.csv
# Skipping file with unexpected format: 772_WearTime.csv
# Skipping file with unexpected format: 771_WearTime.csv
# Skipping file with unexpected format: 776_WearTime.csv
# Skipping file with unexpected format: 775_WearTime.csv
# Skipping file with unexpected format: 778_WearTime.csv
# Skipping file with unexpected format: 780_WearTime.csv
# Skipping file with unexpected format: 777_WearTime.csv
# Skipping file with unexpected format: 782_WearTime.csv
# Skipping file with unexpected format: 781_WearTime.csv
# Skipping file with unexpected format: 785_WearTime.csv
# Skipping file with unexpected format: 786_WearTime.csv
# Skipping file with unexpected format: 788_WearTime.csv
# Skipping file with unexpected format: 784_WearTime.csv
# Skipping file with unexpected format: 790_WearTime.csv
# Skipping file with unexpected format: 792_WearTime.csv
# Skipping file with unexpected format: 1121-9-04-2024_WearTime.csv
# Skipping file with unexpected format: 1249-3-19-2025_WearTime.csv
# Found no duplicates.
# Matches:
# Boost ID: 8022
#   - 1023_2-7-2025_WearTime.csv (Lab ID: 1023, Date: 2025-02-07 00:00:00)
#   - 1023_4-17-2025_WearTime.csv (Lab ID: 1023, Date: 2025-04-17 00:00:00)
# Boost ID: 7062
#   - 1043_2-22-2025_WearTime.csv (Lab ID: 1043, Date: 2025-02-22 00:00:00)
# Boost ID: 7146
#   - 1051_5-5-2025_WearTime.csv (Lab ID: 1051, Date: 2025-05-05 00:00:00)
# Boost ID: 6011
#   - 1093_8-10-2024_WearTime.csv (Lab ID: 1093, Date: 2024-08-10 00:00:00)
# Boost ID: 6013
#   - 1098_8-15-2024_WearTime.csv (Lab ID: 1098, Date: 2024-08-15 00:00:00)
# Boost ID: 6022, 7143
#   - 1108_5-8-2025_WearTime.csv (Lab ID: 1108, Date: 2025-05-08 00:00:00)
# Boost ID: 7001
#   - 1111_9-6-2024_WearTime.csv (Lab ID: 1111, Date: 2024-09-06 00:00:00)
# Boost ID: 7002
#   - 1112_8-8-2024_WearTime.csv (Lab ID: 1112, Date: 2024-08-08 00:00:00)
# Boost ID: 7003
#   - 1113_8-21-2024_WearTime.csv (Lab ID: 1113, Date: 2024-08-21 00:00:00)
# Boost ID: 7004
#   - 1114_9-5-2024_WearTime.csv (Lab ID: 1114, Date: 2024-09-05 00:00:00)
# Boost ID: 7006
#   - 1115_8-6-2024_WearTime.csv (Lab ID: 1115, Date: 2024-08-06 00:00:00)
# Boost ID: 7012
#   - 1116_8-30-2024_WearTime.csv (Lab ID: 1116, Date: 2024-08-30 00:00:00)
# Boost ID: 7009
#   - 1117_8-7-2024_WearTime.csv (Lab ID: 1117, Date: 2024-08-07 00:00:00)
# Boost ID: 7010
#   - 1118_8-9-2024_WearTime.csv (Lab ID: 1118, Date: 2024-08-09 00:00:00)
# Boost ID: 7015
#   - 1120_8-14-2024_WearTime.csv (Lab ID: 1120, Date: 2024-08-14 00:00:00)
# Boost ID: 7017
#   - 1122_8-23-2024_WearTime.csv (Lab ID: 1122, Date: 2024-08-23 00:00:00)
# Boost ID: 8001
#   - 1123_9-21-2024_WearTime.csv (Lab ID: 1123, Date: 2024-09-21 00:00:00)
# Boost ID: 8002
#   - 1124_9-14-2024_WearTime.csv (Lab ID: 1124, Date: 2024-09-14 00:00:00)
#   - 1124_11-7-2024_WearTime.csv (Lab ID: 1124, Date: 2024-11-07 00:00:00)
#   - 1124_2-26-2025_WearTime.csv (Lab ID: 1124, Date: 2025-02-26 00:00:00)
#   - 1124_5-5-2025_WearTime.csv (Lab ID: 1124, Date: 2025-05-05 00:00:00)
# Boost ID: 8003
#   - 1125_10-5-2024_WearTime.csv (Lab ID: 1125, Date: 2024-10-05 00:00:00)
#   - 1125_2-1-2025_WearTime.csv (Lab ID: 1125, Date: 2025-02-01 00:00:00)
#   - 1125_5-31-2025_WearTime.csv (Lab ID: 1125, Date: 2025-05-31 00:00:00)
# Boost ID: 8004
#   - 1126_9-26-2024_WearTime.csv (Lab ID: 1126, Date: 2024-09-26 00:00:00)
#   - 1126_11-23-2024_WearTime.csv (Lab ID: 1126, Date: 2024-11-23 00:00:00)
#   - 1126_3-12-2025_WearTime.csv (Lab ID: 1126, Date: 2025-03-12 00:00:00)
#   - 1126_4-30-2025_WearTime.csv (Lab ID: 1126, Date: 2025-04-30 00:00:00)
# Boost ID: 8006
#   - 1129_9-21-2024_WearTime.csv (Lab ID: 1129, Date: 2024-09-21 00:00:00)
#   - 1129_12-13-2024_WearTime.csv (Lab ID: 1129, Date: 2024-12-13 00:00:00)
#   - 1129_4-16-2025_WearTime.csv (Lab ID: 1129, Date: 2025-04-16 00:00:00)
#   - 1129_5-14-2025_WearTime.csv (Lab ID: 1129, Date: 2025-05-14 00:00:00)
# Boost ID: 7019
#   - 1130_9-25-2024_WearTime.csv (Lab ID: 1130, Date: 2024-09-25 00:00:00)
# Boost ID: 7020
#   - 1131_10-9-2024_WearTime.csv (Lab ID: 1131, Date: 2024-10-09 00:00:00)
# Boost ID: 7021
#   - 1132_10-3-2024_WearTime.csv (Lab ID: 1132, Date: 2024-10-03 00:00:00)
# Boost ID: 7022
#   - 1133_10-2-2024_WearTime.csv (Lab ID: 1133, Date: 2024-10-02 00:00:00)
# Boost ID: 8005
#   - 1134_10-31-2024_WearTime.csv (Lab ID: 1134, Date: 2024-10-31 00:00:00)
#   - 1134_1-16-2025_WearTime.csv (Lab ID: 1134, Date: 2025-01-16 00:00:00)
#   - 1134_5-22-2025_WearTime.csv (Lab ID: 1134, Date: 2025-05-22 00:00:00)
#   - 1134_6-26-2025_WearTime.csv (Lab ID: 1134, Date: 2025-06-26 00:00:00)
# Boost ID: 7024
#   - 1136_10-12-2024_WearTime.csv (Lab ID: 1136, Date: 2024-10-12 00:00:00)
# Boost ID: 7025
#   - 1137_10-12-2024_WearTime.csv (Lab ID: 1137, Date: 2024-10-12 00:00:00)
# Boost ID: 7026
#   - 1138_10-25-2024_WearTime.csv (Lab ID: 1138, Date: 2024-10-25 00:00:00)
# Boost ID: 7027
#   - 1139_11-8-2024_WearTime.csv (Lab ID: 1139, Date: 2024-11-08 00:00:00)
# Boost ID: 7028
#   - 1140_10-29-2024_WearTime.csv (Lab ID: 1140, Date: 2024-10-29 00:00:00)
# Boost ID: 7029
#   - 1141_11-6-2024_WearTime.csv (Lab ID: 1141, Date: 2024-11-06 00:00:00)
# Boost ID: 7030
#   - 1142_10-25-2024_WearTime.csv (Lab ID: 1142, Date: 2024-10-25 00:00:00)
# Boost ID: 7032
#   - 1144_11-13-2024_WearTime.csv (Lab ID: 1144, Date: 2024-11-13 00:00:00)
# Boost ID: 7033
#   - 1145_11-7-2024_WearTime.csv (Lab ID: 1145, Date: 2024-11-07 00:00:00)
# Boost ID: 8008
#   - 1146_11-5-2024_WearTime.csv (Lab ID: 1146, Date: 2024-11-05 00:00:00)
#   - 1146_1-10-2025_WearTime.csv (Lab ID: 1146, Date: 2025-01-10 00:00:00)
# Boost ID: 7034
#   - 1147_11-15-2024_WearTime.csv (Lab ID: 1147, Date: 2024-11-15 00:00:00)
# Boost ID: 7035
#   - 1148_11-5-2024_WearTime.csv (Lab ID: 1148, Date: 2024-11-05 00:00:00)
# Boost ID: 8011
#   - 1151_12-7-2024_WearTime.csv (Lab ID: 1151, Date: 2024-12-07 00:00:00)
#   - 1151_2-20-2025_WearTime.csv (Lab ID: 1151, Date: 2025-02-20 00:00:00)
# Boost ID: 7031
#   - 1155_12-19-2024_WearTime.csv (Lab ID: 1155, Date: 2024-12-19 00:00:00)
# Boost ID: 8012
#   - 1158_1-9-2025_WearTime.csv (Lab ID: 1158, Date: 2025-01-09 00:00:00)
#   - 1158_5-9-2025_WearTime.csv (Lab ID: 1158, Date: 2025-05-09 00:00:00)
# Boost ID: 8014
#   - 1160_1-15-2025_WearTime.csv (Lab ID: 1160, Date: 2025-01-15 00:00:00)
#   - 1160_5-3-2025_WearTime.csv (Lab ID: 1160, Date: 2025-05-03 00:00:00)
# Boost ID: 7037
#   - 1161_1-18-2025_WearTime.csv (Lab ID: 1161, Date: 2025-01-18 00:00:00)
# Boost ID: 8015
#   - 1162_1-29-2025_WearTime.csv (Lab ID: 1162, Date: 2025-01-29 00:00:00)
# Boost ID: 8016
#   - 1163_2-19-2025_WearTime.csv (Lab ID: 1163, Date: 2025-02-19 00:00:00)
#   - 1163_4-7-2025_WearTime.csv (Lab ID: 1163, Date: 2025-04-07 00:00:00)
# Boost ID: 8017
#   - 1165_4-9-2025_WearTime.csv (Lab ID: 1165, Date: 2025-04-09 00:00:00)
# Boost ID: 7039
#   - 1166_1-21-2025_WearTime.csv (Lab ID: 1166, Date: 2025-01-21 00:00:00)
# Boost ID: 8018
#   - 1167_1-22-2025_WearTime.csv (Lab ID: 1167, Date: 2025-01-22 00:00:00)
#   - 1167_5-21-25_WearTime.csv (Lab ID: 1167, Date: 2025-05-21 00:00:00)
# Boost ID: 8019
#   - 1168_1-28-2025_WearTime.csv (Lab ID: 1168, Date: 2025-01-28 00:00:00)
#   - 1168_4-23-2025_WearTime.csv (Lab ID: 1168, Date: 2025-04-23 00:00:00)
# Boost ID: 8020
#   - 1169_1-30-2025_WearTime.csv (Lab ID: 1169, Date: 2025-01-30 00:00:00)
#   - 1169_4-9-2025_WearTime.csv (Lab ID: 1169, Date: 2025-04-09 00:00:00)
# Boost ID: 8021
#   - 1170_1-29-2025_WearTime.csv (Lab ID: 1170, Date: 2025-01-29 00:00:00)
#   - 1170_5-24-2025_WearTime.csv (Lab ID: 1170, Date: 2025-05-24 00:00:00)
# Boost ID: 7040
#   - 1171_2-8-2025_WearTime.csv (Lab ID: 1171, Date: 2025-02-08 00:00:00)
# Boost ID: 7041
#   - 1172_1-28-2025_WearTime.csv (Lab ID: 1172, Date: 2025-01-28 00:00:00)
#   - 1172_5-29-2025_WearTime.csv (Lab ID: 1172, Date: 2025-05-29 00:00:00)
# Boost ID: 7042
#   - 1173_3-1-2025_WearTime.csv (Lab ID: 1173, Date: 2025-03-01 00:00:00)
# Boost ID: 7043
#   - 1174_1-28-2025_WearTime.csv (Lab ID: 1174, Date: 2025-01-28 00:00:00)
# Boost ID: 7047
#   - 1178_2-12-2025_WearTime.csv (Lab ID: 1178, Date: 2025-02-12 00:00:00)
# Boost ID: 7048
#   - 1179_3-11-2025_WearTime.csv (Lab ID: 1179, Date: 2025-03-11 00:00:00)
# Boost ID: 7049
#   - 1180_2-18-2025_WearTime.csv (Lab ID: 1180, Date: 2025-02-18 00:00:00)
# Boost ID: 7050
#   - 1181_2-21-2025_WearTime.csv (Lab ID: 1181, Date: 2025-02-21 00:00:00)
# Boost ID: 7052
#   - 1183_2-13-2025_WearTime.csv (Lab ID: 1183, Date: 2025-02-13 00:00:00)
# Boost ID: 8023
#   - 1185_4-10-2025_WearTime.csv (Lab ID: 1185, Date: 2025-04-10 00:00:00)
# Boost ID: 8024
#   - 1186_3-8-2025_WearTime.csv (Lab ID: 1186, Date: 2025-03-08 00:00:00)
#   - 1186_5-30-2025_WearTime.csv (Lab ID: 1186, Date: 2025-05-30 00:00:00)
# Boost ID: 7054
#   - 1187_2-11-2025_WearTime.csv (Lab ID: 1187, Date: 2025-02-11 00:00:00)
# Boost ID: 7056
#   - 1190_2-22-2025_WearTime.csv (Lab ID: 1190, Date: 2025-02-22 00:00:00)
# Boost ID: 7057
#   - 1191_2-15-2025_WearTime.csv (Lab ID: 1191, Date: 2025-02-15 00:00:00)
# Boost ID: 7058
#   - 1192_2-21-2025_WearTime.csv (Lab ID: 1192, Date: 2025-02-21 00:00:00)
# Boost ID: 7059
#   - 1193_2-25-2025_WearTime.csv (Lab ID: 1193, Date: 2025-02-25 00:00:00)
# Boost ID: 8026
#   - 1194_2-4-2025_WearTime.csv (Lab ID: 1194, Date: 2025-02-04 00:00:00)
#   - 1194_5-23-2025_WearTime.csv (Lab ID: 1194, Date: 2025-05-23 00:00:00)
# Boost ID: 7061
#   - 1196_2-25-2025_WearTime.csv (Lab ID: 1196, Date: 2025-02-25 00:00:00)
# Boost ID: 7063
#   - 1197_2-25-2025_WearTime.csv (Lab ID: 1197, Date: 2025-02-25 00:00:00)
# Boost ID: 8030
#   - 1200_2-21-2025_WearTime.csv (Lab ID: 1200, Date: 2025-02-21 00:00:00)
#   - 1200_5-10-2025_WearTime.csv (Lab ID: 1200, Date: 2025-05-10 00:00:00)
# Boost ID: 7064
#   - 1202_3-1-2025_WearTime.csv (Lab ID: 1202, Date: 2025-03-01 00:00:00)
# Boost ID: 7067
#   - 1205_2-21-2025_WearTime.csv (Lab ID: 1205, Date: 2025-02-21 00:00:00)
# Boost ID: 7068
#   - 1206_2-27-2025_WearTime.csv (Lab ID: 1206, Date: 2025-02-27 00:00:00)
# Boost ID: 7069
#   - 1207_3-1-2025_WearTime.csv (Lab ID: 1207, Date: 2025-03-01 00:00:00)
# Boost ID: 7072
#   - 1210_3-1-2025_WearTime.csv (Lab ID: 1210, Date: 2025-03-01 00:00:00)
# Boost ID: 7073
#   - 1211_3-1-2025_wearTime.csv (Lab ID: 1211, Date: 2025-03-01 00:00:00)
# Boost ID: 7075
#   - 1213_3-4-2025_WearTime.csv (Lab ID: 1213, Date: 2025-03-04 00:00:00)
# Boost ID: 7076
#   - 1214_3-11-2025_WearTime.csv (Lab ID: 1214, Date: 2025-03-11 00:00:00)
# Boost ID: 7077
#   - 1215_3-14-2025_WearTime.csv (Lab ID: 1215, Date: 2025-03-14 00:00:00)
# Boost ID: 7078
#   - 1216_3-8-2025_WearTime.csv (Lab ID: 1216, Date: 2025-03-08 00:00:00)
# Boost ID: 7079
#   - 1217_3-13-2025_WearTime.csv (Lab ID: 1217, Date: 2025-03-13 00:00:00)
# Boost ID: 7080
#   - 1218_3-7-2025_WearTime.csv (Lab ID: 1218, Date: 2025-03-07 00:00:00)
# Boost ID: 7082
#   - 1220_3-29-2025_WearTime.csv (Lab ID: 1220, Date: 2025-03-29 00:00:00)
# Boost ID: 8032
#   - 1221_5-22-2025_WearTime.csv (Lab ID: 1221, Date: 2025-05-22 00:00:00)
# Boost ID: 7083
#   - 1222_3-6-2025_WearTime.csv (Lab ID: 1222, Date: 2025-03-06 00:00:00)
# Boost ID: 7084
#   - 1223_3-29-2025_WearTime.csv (Lab ID: 1223, Date: 2025-03-29 00:00:00)
# Boost ID: 7085
#   - 1224_3-18-2025_WearTime.csv (Lab ID: 1224, Date: 2025-03-18 00:00:00)
# Boost ID: 7086
#   - 1225_3-6-2025_WearTime.csv (Lab ID: 1225, Date: 2025-03-06 00:00:00)
# Boost ID: 7087
#   - 1226_3-6-2025_WearTime.csv (Lab ID: 1226, Date: 2025-03-06 00:00:00)
# Boost ID: 7088
#   - 1227_4-3-2025_WearTime.csv (Lab ID: 1227, Date: 2025-04-03 00:00:00)
# Boost ID: 7089
#   - 1228_3-20-2025_WearTime.csv (Lab ID: 1228, Date: 2025-03-20 00:00:00)
# Boost ID: 7093
#   - 1232_3-12-2025_WearTime.csv (Lab ID: 1232, Date: 2025-03-12 00:00:00)
# Boost ID: 7094
#   - 1233_3-27-2025_WearTime.csv (Lab ID: 1233, Date: 2025-03-27 00:00:00)
# Boost ID: 7065
#   - 1234_3-20-2025_WearTime.csv (Lab ID: 1234, Date: 2025-03-20 00:00:00)
# Boost ID: 7096
#   - 1236_3-29-2025_WearTime.csv (Lab ID: 1236, Date: 2025-03-29 00:00:00)
# Boost ID: 7098
#   - 1239_4-5-2025_WearTime.csv (Lab ID: 1239, Date: 2025-04-05 00:00:00)
# Boost ID: 7102
#   - 1242_2-28-2025_WearTime.csv (Lab ID: 1242, Date: 2025-02-28 00:00:00)
# Boost ID: 7045
#   - 1243_3-20-2025_WearTime.csv (Lab ID: 1243, Date: 2025-03-20 00:00:00)
# Boost ID: 7103
#   - 1244_4-3-2025_WearTime.csv (Lab ID: 1244, Date: 2025-04-03 00:00:00)
# Boost ID: 7104
#   - 1245_4-3-2025_WearTime.csv (Lab ID: 1245, Date: 2025-04-03 00:00:00)
# Boost ID: 7105
#   - 1246_3-14-2025_WearTime.csv (Lab ID: 1246, Date: 2025-03-14 00:00:00)
# Boost ID: 8034
#   - 1248_3-29-2025_WearTime.csv (Lab ID: 1248, Date: 2025-03-29 00:00:00)
# Boost ID: 8035
#   - 1249_5-31-2025_WearTime.csv (Lab ID: 1249, Date: 2025-05-31 00:00:00)
# Boost ID: 7091
#   - 1250_3-27-2025_WearTime.csv (Lab ID: 1250, Date: 2025-03-27 00:00:00)
# Boost ID: 7070
#   - 1251_4-5-2025_WearTime.csv (Lab ID: 1251, Date: 2025-04-05 00:00:00)
# Boost ID: 7106
#   - 1252_3-28-2025_WearTime.csv (Lab ID: 1252, Date: 2025-03-28 00:00:00)
# Boost ID: 7107
#   - 1254_4-12-2025_WearTime.csv (Lab ID: 1254, Date: 2025-04-12 00:00:00)
# Boost ID: 7108
#   - 1255_3-14-2025_WearTime.csv (Lab ID: 1255, Date: 2025-03-14 00:00:00)
# Boost ID: 7110
#   - 1257_4-4-2025_WearTime.csv (Lab ID: 1257, Date: 2025-04-04 00:00:00)
# Boost ID: 7092
#   - 1260_3-28-2025_WearTime.csv (Lab ID: 1260, Date: 2025-03-28 00:00:00)
# Boost ID: 7090
#   - 1261_4-11-2025_WearTime.csv (Lab ID: 1261, Date: 2025-04-11 00:00:00)
# Boost ID: 7113
#   - 1262_4-4-2025_WearTime.csv (Lab ID: 1262, Date: 2025-04-04 00:00:00)
# Boost ID: 7114
#   - 1263_3-29-2025_WearTime.csv (Lab ID: 1263, Date: 2025-03-29 00:00:00)
# Boost ID: 7097
#   - 1264_4-5-2025_WearTime.csv (Lab ID: 1264, Date: 2025-04-05 00:00:00)
# Boost ID: 7115
#   - 1265_4-2-2025_WearTime.csv (Lab ID: 1265, Date: 2025-04-02 00:00:00)
# Boost ID: 7116
#   - 1266_4-3-2025_WearTime.csv (Lab ID: 1266, Date: 2025-04-03 00:00:00)
# Boost ID: 7117
#   - 1267_3-22-2025_WearTime.csv (Lab ID: 1267, Date: 2025-03-22 00:00:00)
# Boost ID: 7118
#   - 1268_4-8-2025_WearTime.csv (Lab ID: 1268, Date: 2025-04-08 00:00:00)
# Boost ID: 7120
#   - 1270_4-12-2025_WearTime.csv (Lab ID: 1270, Date: 2025-04-12 00:00:00)
# Boost ID: 7122
#   - 1272_4-5-2025_WearTime.csv (Lab ID: 1272, Date: 2025-04-05 00:00:00)
# Boost ID: 7111
#   - 1275_4-18-2025_WearTime.csv (Lab ID: 1275, Date: 2025-04-18 00:00:00)
# Boost ID: 8037
#   - 1276_4-4-2025_WearTime.csv (Lab ID: 1276, Date: 2025-04-04 00:00:00)
# Boost ID: 7124
#   - 1290_4-10-2025_WearTime.csv (Lab ID: 1290, Date: 2025-04-10 00:00:00)
# Boost ID: 7125
#   - 1291_4-10-2025_WearTime.csv (Lab ID: 1291, Date: 2025-04-10 00:00:00)
# Boost ID: 7128
#   - 1298_4-18-2025_WearTime.csv (Lab ID: 1298, Date: 2025-04-18 00:00:00)
# Boost ID: 7129
#   - 1299_4-19-2025_WearTime.csv (Lab ID: 1299, Date: 2025-04-19 00:00:00)
# Boost ID: 7130
#   - 1300_4-18-2025_WearTime.csv (Lab ID: 1300, Date: 2025-04-18 00:00:00)
# Boost ID: 8038
#   - 1302_4-26-2025_WearTime.csv (Lab ID: 1302, Date: 2025-04-26 00:00:00)
# Boost ID: 7133
#   - 1304_4-29-2025_WearTime.csv (Lab ID: 1304, Date: 2025-04-29 00:00:00)
# Boost ID: 7132
#   - 1305_4-24-2025_WearTime.csv (Lab ID: 1305, Date: 2025-04-24 00:00:00)
# Boost ID: 7134
#   - 1311_5-1-2025_WearTime.csv (Lab ID: 1311, Date: 2025-05-01 00:00:00)
# Boost ID: 7136
#   - 1313_6-3-2025_WearTime.csv (Lab ID: 1313, Date: 2025-06-03 00:00:00)
# Boost ID: 8039
#   - 1314_5-20-2025_WearTime.csv (Lab ID: 1314, Date: 2025-05-20 00:00:00)
# Boost ID: 7137
#   - 1315_5-5-2025_WearTime.csv (Lab ID: 1315, Date: 2025-05-05 00:00:00)
# Boost ID: 8040
#   - 1317_5-20-2025_WearTime.csv (Lab ID: 1317, Date: 2025-05-20 00:00:00)
# Boost ID: 8042
#   - 1320_5-20-2025_WearTime.csv (Lab ID: 1320, Date: 2025-05-20 00:00:00)
# Boost ID: 7138
#   - 1321_5-17-2025_WearTime.csv (Lab ID: 1321, Date: 2025-05-17 00:00:00)
# Boost ID: 7139
#   - 1322_5-10-2025_WearTime.csv (Lab ID: 1322, Date: 2025-05-10 00:00:00)
# Boost ID: 7140
#   - 1323_5-10-2025_Sleep.csv (Lab ID: 1323, Date: 2025-05-10 00:00:00)
# Boost ID: 7141
#   - 1324_5-17-2025_WearTime.csv (Lab ID: 1324, Date: 2025-05-17 00:00:00)
# Boost ID: 7142
#   - 1325_5-21-2025_WearTime.csv (Lab ID: 1325, Date: 2025-05-21 00:00:00)
# Boost ID: 7145
#   - 1327_5-10-2025_WearTime.csv (Lab ID: 1327, Date: 2025-05-10 00:00:00)
# Boost ID: 7147
#   - 1328_6-24-25_WearTime.csv (Lab ID: 1328, Date: 2025-06-24 00:00:00)
# Boost ID: 8046
#   - 1330_5-28-2025_WearTime.csv (Lab ID: 1330, Date: 2025-05-28 00:00:00)
# Boost ID: 7150
#   - 1332_5-24-2025_WearTime.csv (Lab ID: 1332, Date: 2025-05-24 00:00:00)
# Boost ID: 7151
#   - 1333_5-13-2025_WearTime.csv (Lab ID: 1333, Date: 2025-05-13 00:00:00)
# Boost ID: 7152
#   - 1334_5-24-2025_WearTime.csv (Lab ID: 1334, Date: 2025-05-24 00:00:00)
# Boost ID: 8047
#   - 1335_5-14-2025_WearTime.csv (Lab ID: 1335, Date: 2025-05-14 00:00:00)
# Boost ID: 8048
#   - 1336_6-6-2025_WearTime.csv (Lab ID: 1336, Date: 2025-06-06 00:00:00)
# Boost ID: 7153
#   - 1337_5-17-2025_WearTime.csv (Lab ID: 1337, Date: 2025-05-17 00:00:00)
# Boost ID: 7155
#   - 1340_6-3-2025_WearTime.csv (Lab ID: 1340, Date: 2025-06-03 00:00:00)
# Boost ID: 8050
#   - 1341_5-21-2025_WearTime.csv (Lab ID: 1341, Date: 2025-05-21 00:00:00)
# Boost ID: 7156
#   - 1342_5-24-2025_WearTime.csv (Lab ID: 1342, Date: 2025-05-24 00:00:00)
# Boost ID: 8051
#   - 1343_6-5-2025_WearTime.csv (Lab ID: 1343, Date: 2025-06-05 00:00:00)
# Boost ID: 7157
#   - 1344_5-16-2025_WearTime.csv (Lab ID: 1344, Date: 2025-05-16 00:00:00)
# Boost ID: 8052
#   - 1345_5-28-2025_WearTime.csv (Lab ID: 1345, Date: 2025-05-28 00:00:00)
# Boost ID: 8053
#   - 1346_6-4-2025_WearTime.csv (Lab ID: 1346, Date: 2025-06-04 00:00:00)
# Boost ID: 8054
#   - 1347_5-30-2025_WearTime.csv (Lab ID: 1347, Date: 2025-05-30 00:00:00)
# Boost ID: 7158
#   - 1348_6-5-2025_Sleep.csv (Lab ID: 1348, Date: 2025-06-05 00:00:00)
# Boost ID: 7159
#   - 1349_6-5-2025_WearTime.csv (Lab ID: 1349, Date: 2025-06-05 00:00:00)
# Boost ID: 7160
#   - 1350_6-4-2025_WearTime.csv (Lab ID: 1350, Date: 2025-06-04 00:00:00)
# Boost ID: 7164
#   - 1354_6-12-2025_WearTime.csv (Lab ID: 1354, Date: 2025-06-12 00:00:00)
# Boost ID: 7165
#   - 1355_6-12-2025_WearTime.csv (Lab ID: 1355, Date: 2025-06-12 00:00:00)
# Boost ID: 7161
#   - 1356_6-10-2025_WearTime.csv (Lab ID: 1356, Date: 2025-06-10 00:00:00)
# Boost ID: 7167
#   - 1358_6-21-2025_WearTime.csv (Lab ID: 1358, Date: 2025-06-21 00:00:00)
# Boost ID: 7168
#   - 1359_6-20-2025_WearTime.csv (Lab ID: 1359, Date: 2025-06-20 00:00:00)
# Boost ID: 7170
#   - 1361_6-10-2025_WearTime.csv (Lab ID: 1361, Date: 2025-06-10 00:00:00)
# Boost ID: 7172
#   - 1363_6-18-2025_WearTime.csv (Lab ID: 1363, Date: 2025-06-18 00:00:00)
# Boost ID: 7174
#   - 1365_6-28-2025_WearTime.csv (Lab ID: 1365, Date: 2025-06-28 00:00:00)
# Boost ID: 7175
#   - 1366_7-2-2025_WearTime.csv (Lab ID: 1366, Date: 2025-07-02 00:00:00)
# Boost ID: 7178
#   - 1369_6-26-2025_WearTime.csv (Lab ID: 1369, Date: 2025-06-26 00:00:00)
# Boost ID: 7180
#   - 1372_7-2-2025_WearTime.csv (Lab ID: 1372, Date: 2025-07-02 00:00:00)
# Boost ID: 8056
#   - 1373_7-3-2025_WearTime.csv (Lab ID: 1373, Date: 2025-07-03 00:00:00)
#
# Duplicates:
#
# Sessions DataFrame:
#     subject_id session_id                                           filename  \
# 0     sub-8022      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 1     sub-8022      ses-2  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 2     sub-7062      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 3     sub-7146      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 4     sub-6011      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# ..         ...        ...                                                ...
# 197   sub-7174      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 198   sub-7175      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 199   sub-7178      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 200   sub-7180      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
# 201   sub-8056      ses-1  /mnt/rdss/VossLab/Repositories/Accelerometer_D...
#
#           date
# 0   2025-02-07
# 1   2025-04-17
# 2   2025-02-22
# 3   2025-05-05
# 4   2024-08-10
# ..         ...
# 197 2025-06-28
# 198 2025-07-02
# 199 2025-06-26
# 200 2025-07-02
# 201 2025-07-03
#
# [202 rows x 4 columns]
# /tmp/nix-shell.RrgKp6/ipykernel_184880/761771891.py:154: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
sessions_df.to_clipboard()

# %%
s8022_test = [pd.read_csv(sessions_df.iloc[0]['filename'],skiprows=1), pd.read_csv(sessions_df.iloc[1]['filename'],skiprows=1)]

# %%
test_s1 = s8022_test[0]
test_s2 = s8022_test[1]
test_s1
# Out:
#                   Date Wear Time (minutes) Non-Wear Time (minutes)  \
# 0             2/7/2025                1321                     119
# 1             2/8/2025                1439                       1
# 2             2/9/2025                1440                       0
# 3            2/10/2025                1440                       0
# 4            2/11/2025                1440                       0
# 5            2/12/2025                1440                       0
# 6            2/13/2025                1440                       0
# 7            2/14/2025                1440                       0
# 8            2/15/2025                1348                      92
# 9            2/16/2025                   0                    1440
# 10     Date/Time Start      Date/Time Stop        Wear or Non-Wear
# 11   2/7/2025 12:00 AM    2/7/2025 6:55 AM                    Wear
# 12    2/7/2025 6:55 AM    2/7/2025 7:28 AM                Non-Wear
# 13    2/7/2025 7:28 AM    2/7/2025 5:21 PM                    Wear
# 14    2/7/2025 5:21 PM    2/7/2025 6:47 PM                Non-Wear
# 15    2/7/2025 6:47 PM   2/8/2025 10:05 AM                    Wear
# 16   2/8/2025 10:05 AM   2/8/2025 10:06 AM                Non-Wear
# 17   2/8/2025 10:06 AM  2/15/2025 10:28 PM                    Wear
# 18  2/15/2025 10:28 PM  2/17/2025 12:00 AM                Non-Wear
#
#               Wear % Non-Wear %  Vector Magnitude
# 0               91.7        8.3         1060314.3
# 1               99.9        0.1         1997886.7
# 2                100          0         1882234.5
# 3                100          0         1647210.0
# 4                100          0         1820595.0
# 5                100          0         1382595.7
# 6                100          0         2210102.8
# 7                100          0         1688519.2
# 8               93.6        6.4         1319762.8
# 9                  0        100            1586.9
# 10  Length (minutes)       Use?               NaN
# 11               415       TRUE               NaN
# 12                33      FALSE               NaN
# 13               593       TRUE               NaN
# 14                86      FALSE               NaN
# 15               918       TRUE               NaN
# 16                 1      FALSE               NaN
# 17             10822       TRUE               NaN
# 18              1532      FALSE               NaN

# %%
# 2) Find the index of the row where your second header lives
hdr_idx = test_s1.index[test_s1.iloc[:, 0] == "Date/Time Start"][0]

# 3) Pull out that row’s values to use as your new column names
new_header = test_s1.iloc[hdr_idx]

# 4) Drop everything up through that header row, reset the index
test_s1 = test_s1.iloc[hdr_idx+1 : ].reset_index(drop=True)

# 5) Assign the new_header as the DataFrame’s columns
test_s1.columns = new_header
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 2
#       1 # 2) Find the index of the row where your second header lives
# ----> 2 hdr_idx = test_s1.index[test_s1.iloc[:, 0] == "Date/Time Start"][0]
#       4 # 3) Pull out that row’s values to use as your new column names
#       5 new_header = test_s1.iloc[hdr_idx]
#
# File /nix/store/59bmf68pd17hp8cphcrpijv7cjs3frwh-python3.13-pandas-2.2.3/lib/python3.13/site-packages/pandas/core/indexes/base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
#    5392     # This case is separated from the conditional above to avoid
#    5393     # pessimization com.is_bool_indexer and ndim checks.
#    5394     return self._getitem_slice(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
test_s1
# Out:
# 10     Date/Time Start      Date/Time Stop Wear or Non-Wear Length (minutes)  \
# 0    2/7/2025 12:00 AM    2/7/2025 6:55 AM             Wear              415
# 1     2/7/2025 6:55 AM    2/7/2025 7:28 AM         Non-Wear               33
# 2     2/7/2025 7:28 AM    2/7/2025 5:21 PM             Wear              593
# 3     2/7/2025 5:21 PM    2/7/2025 6:47 PM         Non-Wear               86
# 4     2/7/2025 6:47 PM   2/8/2025 10:05 AM             Wear              918
# 5    2/8/2025 10:05 AM   2/8/2025 10:06 AM         Non-Wear                1
# 6    2/8/2025 10:06 AM  2/15/2025 10:28 PM             Wear            10822
# 7   2/15/2025 10:28 PM  2/17/2025 12:00 AM         Non-Wear             1532
#
# 10   Use?  NaN
# 0    TRUE  NaN
# 1   FALSE  NaN
# 2    TRUE  NaN
# 3   FALSE  NaN
# 4    TRUE  NaN
# 5   FALSE  NaN
# 6    TRUE  NaN
# 7   FALSE  NaN

# %%
test_s1 = test_s1[['Date/Time Start', 'Date/Time Stop', 'Wear or Non-Wear']]

# %%
test_s1 = test_s1[test_s1['Wear or Non-Wear']=='Non-Wear']

# %%
nonwear_df = test_s1
nonwear_df
# Out:
# 10     Date/Time Start      Date/Time Stop Wear or Non-Wear
# 1     2/7/2025 6:55 AM    2/7/2025 7:28 AM         Non-Wear
# 3     2/7/2025 5:21 PM    2/7/2025 6:47 PM         Non-Wear
# 5    2/8/2025 10:05 AM   2/8/2025 10:06 AM         Non-Wear
# 7   2/15/2025 10:28 PM  2/17/2025 12:00 AM         Non-Wear

# %%
int_sleep = pd.read_csv('/mnt/lss/Projects/BOOST/InterventionStudy/3-experiment/data/act-int-test/sleep_log_intervention.csv')
int_sleep.to_clipboard()

# %%
sleep_test = int_sleep[int_sleep['ID']=='sub-8022_ses-1_accel']
sleep_test.to_clipboard()
sleep_df = sleep_test

# %%
import pandas as pd

# 1) parse your nonwear datetimes and extract just the date
nonwear_df['Date/Time Start'] = pd.to_datetime(nonwear_df['Date/Time Start'])
nonwear_df['Date/Time Stop' ] = pd.to_datetime(nonwear_df['Date/Time Stop'])
nonwear_df['nw_date']       = nonwear_df['Date/Time Start'].dt.date

# 2) build a dict: date → list of (start_time_str, stop_time_str)
nw_dict = {
    d: list(zip(
        grp['Date/Time Start'].dt.strftime('%H:%M:%S'),
        grp['Date/Time Stop' ].dt.strftime('%H:%M:%S'),
    ))
    for d, grp in nonwear_df.groupby('nw_date')
}

# 3) make sure your sleep dates are actual date objects
for i in range(1, 11):
    col = f'D{i}_date'
    if col in sleep_df.columns:
        sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date

# 4) for each row and each day, pluck out the intervals and write new cols
for idx, row in sleep_df.iterrows():
    for i in range(1, 11):
        date_col = f'D{i}_date'
        if pd.isna(row.get(date_col)):
            continue

        day = row[date_col]
        intervals = nw_dict.get(day, [])

        for j, (off_time, on_time) in enumerate(intervals, start=1):
            off_col = f'D{i}_nonwear{j}_off'
            on_col  = f'D{i}_nonwear{j}_on'

            # create the column if it doesn’t exist yet
            if off_col not in sleep_df.columns:
                sleep_df[off_col] = pd.NA
            if on_col not in sleep_df.columns:
                sleep_df[on_col]  = pd.NA

            # assign the times
            sleep_df.at[idx, off_col] = off_time
            sleep_df.at[idx, on_col ] = on_time
# Out:
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[col] = pd.to_datetime(sleep_df[col]).dt.date
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[off_col] = pd.NA
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[on_col]  = pd.NA
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[off_col] = pd.NA
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[on_col]  = pd.NA
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[off_col] = pd.NA
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[on_col]  = pd.NA
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[off_col] = pd.NA
# /tmp/nix-shell.RrgKp6/ipykernel_184880/3756629236.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sleep_df[on_col]  = pd.NA

# %%
sleep_df
# Out:
#                      ID     D1_date  D1_inbed D1_wakeup     D2_date  D2_inbed  \
# 0  sub-8022_ses-1_accel  2025-02-07  19:00:00  08:30:00  2025-02-08  23:45:00
#
#   D2_wakeup     D3_date  D3_inbed D3_wakeup  ... D10_inbed D10_wakeup  \
# 0  07:30:00  2025-02-09  23:55:00  07:00:00  ...       NaN        NaN
#
#   D1_nonwear1_off D1_nonwear1_on D1_nonwear2_off D1_nonwear2_on  \
# 0        06:55:00       07:28:00        17:21:00       18:47:00
#
#   D2_nonwear1_off D2_nonwear1_on D8_nonwear1_off D8_nonwear1_on
# 0        10:05:00       10:06:00        22:28:00       00:00:00
#
# [1 rows x 39 columns]

# %%
import pandas as pd

def integrate_nonwear(sleep_df: pd.DataFrame,
                      wear_files_df: pd.DataFrame,
                      id_col: str = "ID") -> pd.DataFrame:
    """
    Updates sleep_df in‑place by reading each wear‑time CSV in wear_files_df,
    extracting Non‑Wear intervals, and appending them to the matching row
    in sleep_df under D{day}_nonwear{n}_{off,on} columns.
    
    wear_files_df must have columns: subject_id, session_id, filename, date
    sleep_df must have an ID column like "sub-8022_ses-1_accel" and
      D1_date … D10_date columns of type date or datetime.
    """
    for _, wf in wear_files_df.iterrows():
        # build the sleep_df ID key
        key = f"{wf.subject_id}_{wf.session_id}_accel"

        # 1) read raw CSV and splice out the non-wear table
        raw = pd.read_csv(wf.filename, header=0, dtype=str)
        # locate the second-header row
        mask = (raw.iloc[:,0]
                .astype(str)
                .str.strip()
                .str.contains("Date/Time Start", na=False))
        if not mask.any():
            continue  # no header found, skip
        hdr_idx = mask.idxmax()
        new_hdr = raw.iloc[hdr_idx]
        df = raw.iloc[hdr_idx+1 : ].reset_index(drop=True)
        df.columns = new_hdr
        df = df[['Date/Time Start','Date/Time Stop','Wear or Non-Wear']]
        nonwear = df[df['Wear or Non-Wear']=='Non-Wear'].copy()

        # 2) parse datetimes and group by date
        nonwear['Date/Time Start'] = pd.to_datetime(nonwear['Date/Time Start'])
        nonwear['Date/Time Stop']  = pd.to_datetime(nonwear['Date/Time Stop'])
        nonwear['nw_date']         = nonwear['Date/Time Start'].dt.date
        nw_dict = (
            nonwear
            .groupby('nw_date')
            .apply(lambda g: list(zip(
                g['Date/Time Start'].dt.strftime('%H:%M:%S'),
                g['Date/Time Stop'].dt.strftime('%H:%M:%S'),
            )))
            .to_dict()
        )

        # 3) find matching sleep_df row
        matches = sleep_df.index[sleep_df[id_col] == key]
        if len(matches) == 0:
            continue
        ridx = matches[0]

        # 4) for each D{i}_date, assign its intervals
        for i in range(1, 11):
            date_col = f'D{i}_date'
            if date_col not in sleep_df.columns:
                break
            raw_date = sleep_df.at[ridx, date_col]
            if pd.isna(raw_date):
                continue
            day = pd.to_datetime(raw_date).date()
            intervals = nw_dict.get(day, [])
            for j, (off_t, on_t) in enumerate(intervals, start=1):
                off_col = f'D{i}_nonwear{j}_off'
                on_col  = f'D{i}_nonwear{j}_on'
                # create columns if missing
                if off_col not in sleep_df:
                    sleep_df[off_col] = pd.NA
                if on_col not in sleep_df:
                    sleep_df[on_col]  = pd.NA
                sleep_df.at[ridx, off_col] = off_t
                sleep_df.at[ridx, on_col ] = on_t

    return sleep_df

# %%
# sleep_df: your DataFrame of all sleep logs
# wear_files_df: DataFrame with columns [subject_id, session_id, filename, date]
int_sleep = pd.read_csv('/mnt/lss/Projects/BOOST/InterventionStudy/3-experiment/data/act-int-test/sleep_log_intervention.csv')

updated = integrate_nonwear(int_sleep, sessions_df)

# %%
updated
# Out:
#                       ID     D1_date  D1_inbed D1_wakeup     D2_date  \
# 0   sub-8022_ses-1_accel  2025-02-07  19:00:00  08:30:00  2025-02-08
# 1   sub-8022_ses-2_accel  2025-04-17  00:00:00  06:30:00  2025-04-18
# 2   sub-8001_ses-1_accel  2024-09-21  00:30:00  08:30:00  2024-09-22
# 3   sub-8002_ses-1_accel  2024-09-14  22:15:00  06:45:00  2024-09-15
# 4   sub-8002_ses-2_accel  2024-11-07  23:00:00  03:30:00  2024-11-08
# 5   sub-8002_ses-3_accel  2025-02-26  23:00:00  06:30:00  2025-02-27
# 6   sub-8002_ses-4_accel  2025-05-05  22:30:00  06:30:00  2025-05-06
# 7   sub-8003_ses-1_accel  2024-10-05  22:30:00  07:30:00  2024-10-06
# 8   sub-8003_ses-2_accel  2025-02-01  22:50:00  07:00:00  2025-02-02
# 9   sub-8004_ses-1_accel  2024-09-26  18:45:00  05:55:00  2024-09-27
# 10  sub-8004_ses-2_accel  2024-11-23  23:00:00  06:56:00  2024-11-24
# 11  sub-8004_ses-3_accel  2025-03-12  21:15:00  06:45:00  2025-03-13
# 12  sub-8004_ses-4_accel  2025-04-30  21:30:00  05:45:00  2025-05-01
# 13  sub-8006_ses-1_accel  2024-09-21  23:00:00  07:30:00  2024-09-22
# 14  sub-8006_ses-2_accel  2024-12-13  22:00:00  07:00:00  2024-12-14
# 15  sub-8006_ses-3_accel  2025-04-16  23:00:00  06:22:00  2025-04-17
# 16  sub-8006_ses-4_accel  2025-05-14  22:20:00  06:40:00  2025-05-15
# 17  sub-8005_ses-1_accel  2024-10-31  23:00:00  07:30:00  2024-11-01
# 18  sub-8005_ses-2_accel  2025-01-16  22:30:00  06:45:00  2025-01-17
# 19  sub-8005_ses-3_accel  2025-05-22  23:00:00  07:15:00  2025-05-23
# 20  sub-8008_ses-1_accel  2024-11-05  00:00:00  08:00:00  2024-11-06
# 21  sub-8008_ses-2_accel  2025-01-10  03:46:00  09:30:00  2025-01-11
# 22  sub-8011_ses-1_accel  2024-12-07  00:00:00  07:30:00  2024-12-08
# 23  sub-8011_ses-2_accel  2025-02-20  00:00:00  07:53:00  2025-02-21
# 24  sub-8012_ses-1_accel  2025-05-09  23:00:00  07:00:00  2025-05-10
# 25  sub-8012_ses-2_accel  2025-01-09  20:45:00  06:00:00  2025-01-10
# 26  sub-8014_ses-1_accel  2025-01-15  21:15:00  03:50:00  2025-01-16
# 27  sub-8014_ses-2_accel  2025-05-03  23:00:00  07:05:00  2025-05-04
# 28  sub-8015_ses-1_accel  2025-01-29  22:05:00  06:00:00  2025-01-30
# 29  sub-8016_ses-1_accel  2025-02-19  21:53:00  05:30:00  2025-02-20
# 30  sub-8016_ses-2_accel  2025-04-07  22:50:00  05:00:00  2025-04-08
# 31  sub-8017_ses-1_accel  2025-04-09  22:20:00  06:37:00  2025-04-10
# 32  sub-8018_ses-1_accel  2025-01-22  23:30:00  10:15:00  2025-01-23
# 33  sub-8019_ses-1_accel  2025-01-28  23:06:00  06:30:00  2025-01-29
# 34  sub-8019_ses-2_accel  2025-04-23  23:02:00  05:30:00  2025-04-24
# 35  sub-8020_ses-1_accel  2025-01-30  21:30:00  02:30:00  2025-01-31
# 36  sub-8020_ses-2_accel  2025-04-09  19:43:00  05:00:00  2025-04-10
# 37  sub-8021_ses-1_accel  2025-01-29  23:19:00  08:00:00  2025-01-30
# 38  sub-8021_ses-2_accel  2025-05-24  00:00:00  08:20:00  2025-05-25
# 39  sub-8023_ses-1_accel  2025-04-10  23:00:00  05:50:00  2025-04-12
# 40  sub-8024_ses-1_accel  2025-03-08  21:43:00  06:43:00  2025-03-09
# 41  sub-8024_ses-2_accel  2025-05-30  22:30:00  07:30:00  2025-05-31
# 42  sub-8026_ses-1_accel  2025-02-04  20:30:00  05:30:00  2025-02-05
# 43  sub-8026_ses-2_accel  2025-05-23  00:00:00  06:00:00  2025-05-24
# 44  sub-8030_ses-1_accel  2025-02-21  21:30:00  06:10:00  2025-02-22
# 45  sub-8030_ses-2_accel  2025-05-10  22:40:00  07:05:00  2025-05-11
# 46  sub-8032_ses-1_accel  2025-05-22  20:35:00  05:34:00  2025-05-23
# 47  sub-8034_ses-1_accel  2025-03-29  21:30:00  07:30:00  2025-03-30
# 48  sub-8035_ses-1_accel  2025-03-19  21:45:00  05:45:00  2025-03-20
# 49  sub-8036_ses-1_accel  2025-03-25  22:30:00  07:00:00  2025-03-27
# 50  sub-8038_ses-1_accel  2025-04-26  23:30:00  09:50:00  2025-04-27
# 51  sub-8039_ses-1_accel  2025-05-20  23:20:00  05:55:00  2025-05-22
# 52  sub-8040_ses-1_accel  2025-05-20  22:30:00  06:15:00  2025-05-21
# 53  sub-8042_ses-1_accel  2025-05-20  21:17:00  06:13:00  2025-05-21
# 54  sub-8046_ses-1_accel  2025-05-28  22:00:00  06:00:00  2025-05-29
# 55  sub-8047_ses-1_accel  2025-05-14  22:45:00  05:15:00  2025-05-15
# 56  sub-8050_ses-1_accel  2025-05-21  00:00:00  06:30:00  2025-05-22
# 57  sub-8051_ses-1_accel  2025-06-05  01:00:00  07:45:00  2025-06-06
# 58  sub-8053_ses-1_accel  2025-06-04  23:48:00  06:30:00  2025-06-05
# 59  sub-8054_ses-1_accel  2025-05-30  00:00:00  06:45:00  2025-05-31
#
#     D2_inbed D2_wakeup     D3_date  D3_inbed D3_wakeup  ... D7_wakeup  \
# 0   23:45:00  07:30:00  2025-02-09  23:55:00  07:00:00  ...  07:00:00
# 1   23:10:00  07:40:00  2025-04-20  02:45:00  07:30:00  ...  08:00:00
# 2   00:15:00  07:40:00  2024-09-23  05:20:00  09:30:00  ...  09:00:00
# 3   23:00:00  06:45:00  2024-09-16  22:51:00  06:45:00  ...  07:00:00
# 4   21:30:00  05:30:00  2024-11-09  21:30:00  05:30:00  ...  06:15:00
# 5   23:00:00  06:30:00  2025-02-28  23:00:00  07:30:00  ...  07:00:00
# 6   22:30:00  06:30:00  2025-05-07  23:00:00  07:00:00  ...  06:45:00
# 7   21:30:00  06:00:00  2024-10-07  22:00:00  06:00:00  ...       NaN
# 8   22:00:00  06:15:00  2025-02-03  22:30:00  05:30:00  ...  07:15:00
# 9   22:00:00  07:01:00  2024-09-28  21:57:00  06:12:00  ...       NaN
# 10  21:43:00  05:51:00  2024-11-25  20:55:00  05:26:00  ...  06:04:00
# 11  21:00:00  06:15:00  2025-03-14  21:15:00  07:30:00  ...  06:10:00
# 12  22:00:00  06:00:00  2025-05-02  20:45:00  06:00:00  ...  06:15:00
# 13  23:00:00  05:30:00  2024-09-23  22:30:00  06:00:00  ...  07:00:00
# 14  21:00:00  07:00:00  2024-12-15  23:00:00  06:00:00  ...  05:25:00
# 15  23:00:00  06:00:00  2025-04-18  18:00:00  07:00:00  ...  06:20:00
# 16  22:30:00  06:30:00  2025-05-16  23:30:00  06:30:00  ...  06:50:00
# 17  23:30:00  07:45:00  2024-11-02  23:25:00  08:15:00  ...  08:05:00
# 18  23:40:00  08:38:00  2025-01-18  23:50:00  08:50:00  ...  07:50:00
# 19  23:00:00  08:00:00  2025-05-24  23:15:00  08:00:00  ...  07:50:00
# 20  22:30:00  09:00:00  2024-11-07  23:30:00  08:00:00  ...  09:00:00
# 21  02:00:00  10:30:00  2025-01-12  03:00:00  11:00:00  ...  04:30:00
# 22  23:38:00  06:31:00  2024-12-09  22:47:00  06:47:00  ...  07:08:00
# 23  00:23:00  06:30:00  2025-02-22  22:42:00  08:00:00  ...  06:11:00
# 24  23:15:00  06:25:00  2025-05-12  22:00:00  06:25:00  ...  07:45:00
# 25  22:30:00  06:15:00  2025-01-12  20:30:00  06:15:00  ...  05:55:00
# 26  21:00:00  03:50:00  2025-01-17  21:00:00  04:50:00  ...  03:50:00
# 27  21:15:00  03:50:00  2025-05-05  20:25:00  02:50:00  ...  06:15:00
# 28  22:00:00  06:00:00  2025-01-31  22:30:00  07:54:00  ...  06:05:00
# 29  22:07:00  05:30:00  2025-02-21  22:40:00  08:50:00  ...  08:30:00
# 30  22:00:00  05:00:00  2025-04-10  23:15:00  09:15:00  ...  09:15:00
# 31  22:24:00  06:32:00  2025-04-11  22:10:00  08:17:00  ...  06:17:00
# 32  23:30:00  10:00:00  2025-01-24  23:30:00  10:00:00  ...  09:30:00
# 33  23:00:00  06:00:00  2025-01-30  23:17:00  06:00:00  ...  06:00:00
# 34  22:40:00  06:20:00  2025-04-25  23:25:00  07:30:00  ...  06:20:00
# 35  21:00:00  05:00:00  2025-02-01  19:45:00  05:00:00  ...  05:30:00
# 36  19:45:00  05:40:00  2025-04-11  20:53:00  06:00:00  ...  05:30:00
# 37  23:34:00  08:01:00  2025-01-31  23:07:00  09:15:00  ...  07:29:00
# 38  23:45:00  09:00:00  2025-05-26  23:30:00  06:00:00  ...  09:00:00
# 39  22:30:00  09:00:00  2025-04-13  23:00:00  05:15:00  ...  06:15:00
# 40  21:30:00  05:13:00  2025-03-10  20:40:00  04:30:00  ...  06:05:00
# 41  22:00:00  06:00:00  2025-06-01  23:00:00  05:45:00  ...  05:50:00
# 42  21:00:00  06:00:00  2025-02-06  19:30:00  06:00:00  ...  05:30:00
# 43  23:30:00  07:50:00  2025-05-25  23:30:00  08:30:00  ...  05:50:00
# 44  21:30:00  06:04:00  2025-02-23  20:30:00  05:10:00  ...  06:10:00
# 45  22:45:00  06:17:00  2025-05-12  22:30:00  05:17:00  ...  05:59:00
# 46  21:00:00  06:48:00  2025-05-24  20:40:00  07:14:00  ...  05:39:00
# 47  21:30:00  06:00:00  2025-03-31  22:00:00  06:30:00  ...  06:20:00
# 48  22:42:00  06:45:00  2025-03-21  23:50:00  06:00:00  ...  05:37:00
# 49  22:30:00  06:00:00  2025-03-28  21:30:00  02:30:00  ...  06:00:00
# 50  23:15:00  08:04:00  2025-04-28  23:00:00  08:20:00  ...  05:44:00
# 51  23:30:00  06:00:00  2025-05-24  00:05:00  06:00:00  ...       NaN
# 52  22:45:00  06:30:00  2025-05-22  22:45:00  06:15:00  ...  06:45:00
# 53  21:55:00  05:38:00  2025-05-22  22:29:00  06:05:00  ...  06:15:00
# 54  22:28:00  06:20:00  2025-05-30  22:20:00  07:15:00  ...  06:25:00
# 55  22:00:00  05:55:00  2025-05-16  22:20:00  06:36:00  ...  05:52:00
# 56  00:00:00  06:10:00  2025-05-23  00:20:00  06:30:00  ...  07:00:00
# 57  01:00:00  08:00:00  2025-06-07  00:15:00  06:30:00  ...  10:00:00
# 58  23:35:00  07:35:00  2025-06-06  23:15:00  06:30:00  ...  07:10:00
# 59  23:30:00  06:00:00  2025-06-01  23:40:00  06:15:00  ...  05:45:00
#
#        D8_date  D8_inbed D8_wakeup     D9_date  D9_inbed D9_wakeup  \
# 0   2025-02-15  01:00:00  09:00:00         NaN       NaN       NaN
# 1          NaN       NaN       NaN         NaN       NaN       NaN
# 2   2024-09-28  00:30:00  08:45:00  2024-09-29  00:30:00  08:15:00
# 3   2024-09-21  22:30:00  06:45:00  2024-09-22  22:45:00  06:45:00
# 4   2024-11-14  22:45:00  06:15:00  2024-11-15  22:30:00  07:00:00
# 5   2025-03-05  22:30:00  06:30:00  2025-03-06  23:00:00  06:30:00
# 6   2025-05-12  23:15:00  07:00:00  2025-05-13  22:30:00  06:45:00
# 7          NaN       NaN       NaN         NaN       NaN       NaN
# 8   2025-02-08  23:00:00  07:00:00  2025-02-09  22:30:00  06:15:00
# 9          NaN       NaN       NaN         NaN       NaN       NaN
# 10  2024-11-30  19:30:00  06:20:00  2024-12-01  20:30:00  05:40:00
# 11  2025-03-19  20:30:00  06:45:00  2025-03-20  21:00:00  06:00:00
# 12  2025-05-07  21:15:00  06:15:00  2025-05-08  21:30:00  06:00:00
# 13  2024-09-28  21:30:00  06:30:00  2024-09-29  23:00:00  05:30:00
# 14  2024-12-20  23:00:00  08:00:00  2024-12-21  22:00:00  07:10:00
# 15  2025-04-23  21:45:00  06:17:00  2025-04-24  20:00:00  06:30:00
# 16  2025-05-21  21:45:00  06:11:00  2025-05-22  22:00:00  06:40:00
# 17  2024-11-08  00:30:00  08:30:00  2024-11-09  00:15:00  09:15:00
# 18  2025-01-25  00:10:00  07:50:00         NaN       NaN       NaN
# 19  2025-05-30  00:00:00  07:50:00         NaN       NaN       NaN
# 20  2024-11-13  00:00:00  07:30:00  2024-11-14  00:00:00  11:00:00
# 21         NaN       NaN       NaN         NaN       NaN       NaN
# 22  2024-12-15  00:13:00  07:45:00  2024-12-16  00:01:00  06:40:00
# 23  2025-03-01  00:56:00  07:18:00         NaN       NaN       NaN
# 24  2025-05-17  23:30:00  08:45:00         NaN       NaN       NaN
# 25  2025-01-17  21:45:00  07:00:00         NaN       NaN       NaN
# 26  2025-01-22  21:15:00  03:50:00  2025-01-23  21:15:00  03:50:00
# 27  2025-05-10  23:30:00  06:15:00  2025-05-11  21:05:00  02:50:00
# 28  2025-02-06  22:35:00  05:49:00         NaN       NaN       NaN
# 29  2025-02-26  21:00:00  05:50:00  2025-02-27  21:45:00  05:15:00
# 30  2025-04-16  00:30:00  06:20:00         NaN       NaN       NaN
# 31  2025-04-16  22:01:00  06:35:00  2025-04-17  22:20:00  05:30:00
# 32  2025-01-31  00:00:00  09:15:00         NaN       NaN       NaN
# 33  2025-02-05  22:50:00  06:25:00         NaN       NaN       NaN
# 34  2025-04-30  23:10:00  06:30:00  2025-05-01  22:55:00  06:28:00
# 35  2025-02-06  21:30:00  06:00:00  2025-02-07  22:00:00  05:30:00
# 36  2025-04-16  22:34:00  04:00:00  2025-04-17  21:30:00  06:35:00
# 37         NaN       NaN       NaN         NaN       NaN       NaN
# 38         NaN       NaN       NaN         NaN       NaN       NaN
# 39  2025-04-19  01:15:00  08:50:00         NaN       NaN       NaN
# 40  2025-03-15  21:48:00  06:10:00  2025-03-16  21:30:00  05:00:00
# 41  2025-06-06  22:30:00  07:00:00  2025-06-07  23:00:00  07:00:00
# 42  2025-02-11  22:30:00  06:00:00  2025-02-12  21:00:00  06:00:00
# 43  2025-05-30  22:30:00  06:01:00  2025-05-31  23:00:00  08:40:00
# 44  2025-02-28  21:30:00  04:55:00  2025-03-01  22:00:00  04:55:00
# 45  2025-05-17  22:50:00  06:32:00  2025-05-18  23:00:00  05:30:00
# 46  2025-05-29  19:55:00  05:35:00  2025-05-30  20:40:00  05:57:00
# 47  2025-04-05  21:00:00  07:50:00  2025-04-06  21:00:00  07:00:00
# 48  2025-03-26  21:45:00  05:35:00  2025-03-27  21:30:00  05:39:00
# 49         NaN       NaN       NaN         NaN       NaN       NaN
# 50  2025-05-04  23:30:00  08:20:00         NaN       NaN       NaN
# 51         NaN       NaN       NaN         NaN       NaN       NaN
# 52         NaN       NaN       NaN         NaN       NaN       NaN
# 53  2025-05-27  21:55:00  06:15:00  2025-05-28  22:05:00  05:53:00
# 54  2025-06-04  23:00:00  06:15:00  2025-06-05  22:30:00  06:25:00
# 55  2025-05-21  22:10:00  06:00:00  2025-05-22  22:07:00  05:54:00
# 56  2025-05-28  00:30:00  06:30:00  2025-05-29  00:00:00  06:15:00
# 57  2025-06-12  01:50:00  09:00:00  2025-06-13  01:00:00  09:00:00
# 58  2025-06-12  22:01:00  05:30:00         NaN       NaN       NaN
# 59  2025-06-08  00:00:00  06:00:00         NaN       NaN       NaN
#
#       D10_date D10_inbed D10_wakeup
# 0          NaN       NaN        NaN
# 1          NaN       NaN        NaN
# 2   2024-09-30  00:20:00   08:30:00
# 3          NaN       NaN        NaN
# 4          NaN       NaN        NaN
# 5          NaN       NaN        NaN
# 6          NaN       NaN        NaN
# 7          NaN       NaN        NaN
# 8          NaN       NaN        NaN
# 9          NaN       NaN        NaN
# 10         NaN       NaN        NaN
# 11         NaN       NaN        NaN
# 12         NaN       NaN        NaN
# 13         NaN       NaN        NaN
# 14         NaN       NaN        NaN
# 15         NaN       NaN        NaN
# 16         NaN       NaN        NaN
# 17         NaN       NaN        NaN
# 18         NaN       NaN        NaN
# 19         NaN       NaN        NaN
# 20         NaN       NaN        NaN
# 21         NaN       NaN        NaN
# 22         NaN       NaN        NaN
# 23         NaN       NaN        NaN
# 24         NaN       NaN        NaN
# 25         NaN       NaN        NaN
# 26         NaN       NaN        NaN
# 27         NaN       NaN        NaN
# 28         NaN       NaN        NaN
# 29         NaN       NaN        NaN
# 30         NaN       NaN        NaN
# 31         NaN       NaN        NaN
# 32         NaN       NaN        NaN
# 33         NaN       NaN        NaN
# 34         NaN       NaN        NaN
# 35         NaN       NaN        NaN
# 36         NaN       NaN        NaN
# 37         NaN       NaN        NaN
# 38         NaN       NaN        NaN
# 39         NaN       NaN        NaN
# 40         NaN       NaN        NaN
# 41         NaN       NaN        NaN
# 42         NaN       NaN        NaN
# 43         NaN       NaN        NaN
# 44         NaN       NaN        NaN
# 45         NaN       NaN        NaN
# 46         NaN       NaN        NaN
# 47         NaN       NaN        NaN
# 48         NaN       NaN        NaN
# 49         NaN       NaN        NaN
# 50         NaN       NaN        NaN
# 51         NaN       NaN        NaN
# 52         NaN       NaN        NaN
# 53         NaN       NaN        NaN
# 54         NaN       NaN        NaN
# 55         NaN       NaN        NaN
# 56  2025-05-30  00:00:00   06:45:00
# 57  2025-06-14  03:00:00   09:00:00
# 58         NaN       NaN        NaN
# 59         NaN       NaN        NaN
#
# [60 rows x 31 columns]

# %%
updated.to_csv('./sleep_w_nonwear.csv')
