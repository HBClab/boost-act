# %%
import pandas as pd
import numpy as np
import os

# %%
int_sleep = pd.read_csv('/mnt/lss/Projects/BOOST/InterventionStudy/3-experiment/data/act-int-test/sleep_log_intervention.csv')
int_sleep.head()
# Out:
#                      ID     D1_date  D1_inbed D1_wakeup     D2_date  D2_inbed  \
# 0  sub-8022_ses-1_accel  2025-02-07  19:00:00  08:30:00  2025-02-08  23:45:00
# 1  sub-8022_ses-2_accel  2025-04-17  00:00:00  06:30:00  2025-04-18  23:10:00
# 2  sub-8001_ses-1_accel  2024-09-21  00:30:00  08:30:00  2024-09-22  00:15:00
# 3  sub-8002_ses-1_accel  2024-09-14  22:15:00  06:45:00  2024-09-15  23:00:00
# 4  sub-8002_ses-2_accel  2024-11-07  23:00:00  03:30:00  2024-11-08  21:30:00
#
#   D2_wakeup     D3_date  D3_inbed D3_wakeup  ... D7_wakeup     D8_date  \
# 0  07:30:00  2025-02-09  23:55:00  07:00:00  ...  07:00:00  2025-02-15
# 1  07:40:00  2025-04-20  02:45:00  07:30:00  ...  08:00:00         NaN
# 2  07:40:00  2024-09-23  05:20:00  09:30:00  ...  09:00:00  2024-09-28
# 3  06:45:00  2024-09-16  22:51:00  06:45:00  ...  07:00:00  2024-09-21
# 4  05:30:00  2024-11-09  21:30:00  05:30:00  ...  06:15:00  2024-11-14
#
#    D8_inbed D8_wakeup     D9_date  D9_inbed D9_wakeup    D10_date D10_inbed  \
# 0  01:00:00  09:00:00         NaN       NaN       NaN         NaN       NaN
# 1       NaN       NaN         NaN       NaN       NaN         NaN       NaN
# 2  00:30:00  08:45:00  2024-09-29  00:30:00  08:15:00  2024-09-30  00:20:00
# 3  22:30:00  06:45:00  2024-09-22  22:45:00  06:45:00         NaN       NaN
# 4  22:45:00  06:15:00  2024-11-15  22:30:00  07:00:00         NaN       NaN
#
#   D10_wakeup
# 0        NaN
# 1        NaN
# 2   08:30:00
# 3        NaN
# 4        NaN
#
# [5 rows x 31 columns]

# %%
import os
import sys
import logging
import pandas as pd
import requests
from datetime import datetime, timedelta
from io import StringIO

class ID_COMPARISONS:
    
    def __init__(self, token, daysago=None) -> None:
       self.token = token
       self.INT_DIR = 'mnt/lss/Projects/BOOST/InterventionStudy/3-experiment/data/act-int-test'
       self.OBS_DIR = '/mnt/lss/Projects/BOOST/ObservationalStudy/3-experiment/data/act-obs-test'
       self.daysago = daysago
       logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

    def compare_ids(self):
        """
        Pulls all files from RDSS
        Pulls the list from RedCap
        Compares IDs and returns a dictionary with two keys:
          - 'matches': normal matches mapping boost_id to a list of dicts (filename, labID, date)
          - 'duplicates': a list of dictionaries each with lab_id, boost_id, filenames (list), and dates (list)
        """
        # Retrieve the RedCap report and duplicates from report
        report, report_duplicates = self._return_report()
        # Retrieve the full RDSS file list and duplicate files merged with duplicates from report
        rdss, file_duplicates = self._rdss_file_list(report_duplicates, self.daysago)

        # Initialize the result dictionary for normal (non-duplicate) matches
        result = {}

        # Iterate over the rows in the cleaned RedCap report
        for _, row in report.iterrows():
            boost_id = str(row['boost_id'])
            lab_id = str(row['lab_id'])
            
            # Find matching files in the RDSS list
            rdss_matches = rdss[rdss['ID'] == lab_id]
            if not rdss_matches.empty:
                if boost_id not in result:
                    result[boost_id] = []
                for _, match_row in rdss_matches.iterrows():
                    result[boost_id].append({
                        'filename': match_row['filename'],
                        'labID': lab_id,
                        'date': match_row['Date']
                    })
        
        # Process duplicates into the desired structure.
        duplicates_dict = []
        if not file_duplicates.empty:
            # Group by lab_id and boost_id; each group represents one duplicate combination.
            grouped = file_duplicates.groupby(['lab_id', 'boost_id'])
            for (lab_id, boost_id), group in grouped:
                duplicates_dict.append({
                    'lab_id': lab_id,
                    'boost_id': boost_id,
                    'filenames': group['filename'].tolist(),
                    'dates': group['Date'].tolist()
                })
        else:
            logging.info("Found no duplicates.")

        return {'matches': result, 'duplicates': duplicates_dict}

    def _return_report(self):
        """
        pulls the id report from the rdss via redcap api.
        reads the report as a dataframe.
        checks for boost_ids that are associated with multiple lab_ids, logs a critical error,
        and removes these rows from the dataframe.
        separates duplicate rows (based on any column) from the cleaned data.
        
        returns:
            df_cleaned: dataframe with duplicates removed and problematic boost_ids excluded
            duplicate_rows: dataframe of duplicate rows
        """
        url = 'https://redcap.icts.uiowa.edu/redcap/api/'
        data = {
            'token': self.token,
            'content': 'report',
            'report_id': 43327,
            'format': 'csv'
        }
        r = requests.post(url, data=data)
        if r.status_code != 200:
            print(f"error! status code is {r.status_code}")
            sys.exit(1)
        
        df = pd.read_csv(StringIO(r.text))
        
        # identify boost_ids associated with multiple lab_ids.
        boost_id_counts = df.groupby('boost_id')['lab_id'].nunique()
        problematic_boost_ids = boost_id_counts[boost_id_counts > 1].index.tolist()
        
        if problematic_boost_ids:
            logging.critical(f"found boost_id(s) with multiple lab_ids: {', '.join(map(str, problematic_boost_ids))}. "
                            "these entries will be removed from processing.")
            df = df[~df['boost_id'].isin(problematic_boost_ids)]
        
        # identify and separate duplicate rows based on any column.
        duplicate_rows = df[df.duplicated(keep=False)]
        df_cleaned = df.drop_duplicates(keep=False)
        
        if not duplicate_rows.empty:
            logging.info(f"duplicate rows found:\n{duplicate_rows}")
        
        return df_cleaned, duplicate_rows

    def _rdss_file_list(self, duplicates, daysago=None):
        """
        extracts the first string before the space and the date from filenames ending with .csv
        in the specified folder and stores them in a dataframe.
        
        Also, merges the file list with duplicate report entries based on lab_id.
        
        Returns:
            df: DataFrame of all file entries
            merged_df: DataFrame of file entries that match duplicate lab_ids from the report
        """
        extracted_data = []

        # Loop through all files in the rdss_dir folder.
        rdss_dir = '/mnt/rdss/VossLab/Repositories/Accelerometer_Data'
        for filename in os.listdir(rdss_dir):
            if filename.endswith('.csv'):
                try:
                    base_name = filename.split(' ')[0]  # Extract lab_id
                    date_part = filename.split('(')[1].split(')')[0]  # Extract date
                    extracted_data.append({'ID': base_name, 'Date': date_part, 'filename': filename})
                except IndexError:
                    print(f"Skipping file with unexpected format: {filename}")

        df = pd.DataFrame(extracted_data)

        if not df.empty:
            df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

            if daysago:
                cutoff_date = datetime.today() - timedelta(days=daysago)
                df = df[df['Date'] >= cutoff_date]  # Filter files within the last `daysago` days
            else:
                df = df[df['Date'] >= '2024-08-05']  # Filter out rows before the threshold date

        # Filter the file list to only include rows where ID is in the duplicate report (if any)
        if not duplicates.empty:
            matched_df = df[df['ID'].isin(duplicates['lab_id'])]
            # Merge with the duplicates to bring in boost_id information from the report
            merged_df = matched_df.merge(duplicates, left_on='ID', right_on='lab_id')
        else:
            merged_df = pd.DataFrame()

        return df, merged_df

# %%
token = "DE4E2DB72778DACA9B8848574107D2F5"
id = ID_COMPARISONS(token=token, daysago=400)
results = id.compare_ids()
# Out:
# 2025-07-29 10:33:46,042 - CRITICAL - found boost_id(s) with multiple lab_ids: 7023. these entries will be removed from processing.
# 2025-07-29 10:33:46,616 - INFO - Found no duplicates.

# %%
results
# Out:
# {'matches': {'8022': [{'filename': '1023 (2025-02-07)RAW.csv',
#     'labID': '1023',
#     'date': Timestamp('2025-02-07 00:00:00')},
#    {'filename': '1023 (2025-04-17)RAW.csv',
#     'labID': '1023',
#     'date': Timestamp('2025-04-17 00:00:00')}],
#   '7062': [{'filename': '1043 (2025-02-22)RAW.csv',
#     'labID': '1043',
#     'date': Timestamp('2025-02-22 00:00:00')}],
#   '7146': [{'filename': '1051 (2025-05-05)RAW.csv',
#     'labID': '1051',
#     'date': Timestamp('2025-05-05 00:00:00')}],
#   '6011': [{'filename': '1093 (2024-08-09)RAW.csv',
#     'labID': '1093',
#     'date': Timestamp('2024-08-09 00:00:00')}],
#   '6013': [{'filename': '1098 (2024-08-14)RAW.csv',
#     'labID': '1098',
#     'date': Timestamp('2024-08-14 00:00:00')}],
#   '6022, 7143': [{'filename': '1108 (2025-05-08)RAW.csv',
#     'labID': '1108',
#     'date': Timestamp('2025-05-08 00:00:00')}],
#   '7001': [{'filename': '1111 (2024-09-05)RAW.csv',
#     'labID': '1111',
#     'date': Timestamp('2024-09-05 00:00:00')}],
#   '7002': [{'filename': '1112 (2024-08-07)RAW.csv',
#     'labID': '1112',
#     'date': Timestamp('2024-08-07 00:00:00')}],
#   '7003': [{'filename': '1113 (2024-08-20)RAW.csv',
#     'labID': '1113',
#     'date': Timestamp('2024-08-20 00:00:00')}],
#   '7004': [{'filename': '1114 (2024-09-04)RAW.csv',
#     'labID': '1114',
#     'date': Timestamp('2024-09-04 00:00:00')}],
#   '7006': [{'filename': '1115 (2024-08-05)RAW.csv',
#     'labID': '1115',
#     'date': Timestamp('2024-08-05 00:00:00')}],
#   '7012': [{'filename': '1116 (2024-08-29)RAW.csv',
#     'labID': '1116',
#     'date': Timestamp('2024-08-29 00:00:00')}],
#   '7009': [{'filename': '1117 (2024-08-07)RAW.csv',
#     'labID': '1117',
#     'date': Timestamp('2024-08-07 00:00:00')}],
#   '7010': [{'filename': '1118 (2024-08-09)RAW.csv',
#     'labID': '1118',
#     'date': Timestamp('2024-08-09 00:00:00')}],
#   '7015': [{'filename': '1120 (2024-08-13)RAW.csv',
#     'labID': '1120',
#     'date': Timestamp('2024-08-13 00:00:00')}],
#   '7016': [{'filename': '1121 (2024-09-03)RAW.csv',
#     'labID': '1121',
#     'date': Timestamp('2024-09-03 00:00:00')}],
#   '7017': [{'filename': '1122 (2024-08-22)RAW.csv',
#     'labID': '1122',
#     'date': Timestamp('2024-08-22 00:00:00')}],
#   '8001': [{'filename': '1123 (2024-09-20)RAW.csv',
#     'labID': '1123',
#     'date': Timestamp('2024-09-20 00:00:00')}],
#   '8002': [{'filename': '1124 (2024-11-07)RAW.csv',
#     'labID': '1124',
#     'date': Timestamp('2024-11-07 00:00:00')},
#    {'filename': '1124 (2024-09-13)RAW.csv',
#     'labID': '1124',
#     'date': Timestamp('2024-09-13 00:00:00')},
#    {'filename': '1124 (2025-02-26)RAW.csv',
#     'labID': '1124',
#     'date': Timestamp('2025-02-26 00:00:00')},
#    {'filename': '1124 (2025-05-05)RAW.csv',
#     'labID': '1124',
#     'date': Timestamp('2025-05-05 00:00:00')}],
#   '8003': [{'filename': '1125 (2025-02-01)RAW.csv',
#     'labID': '1125',
#     'date': Timestamp('2025-02-01 00:00:00')},
#    {'filename': '1125 (2024-10-04)RAW.csv',
#     'labID': '1125',
#     'date': Timestamp('2024-10-04 00:00:00')},
#    {'filename': '1125 (2025-05-31)RAW.csv',
#     'labID': '1125',
#     'date': Timestamp('2025-05-31 00:00:00')}],
#   '8004': [{'filename': '1126 (2024-09-25)RAW.csv',
#     'labID': '1126',
#     'date': Timestamp('2024-09-25 00:00:00')},
#    {'filename': '1126 (2024-11-22)RAW.csv',
#     'labID': '1126',
#     'date': Timestamp('2024-11-22 00:00:00')},
#    {'filename': '1126 (2025-04-30)RAW.csv',
#     'labID': '1126',
#     'date': Timestamp('2025-04-30 00:00:00')},
#    {'filename': '1126 (2025-03-12)RAW.csv',
#     'labID': '1126',
#     'date': Timestamp('2025-03-12 00:00:00')}],
#   '8006': [{'filename': '1129 (2024-09-20)RAW.csv',
#     'labID': '1129',
#     'date': Timestamp('2024-09-20 00:00:00')},
#    {'filename': '1129 (2024-12-12)RAW.csv',
#     'labID': '1129',
#     'date': Timestamp('2024-12-12 00:00:00')},
#    {'filename': '1129 (2025-05-14)RAW.csv',
#     'labID': '1129',
#     'date': Timestamp('2025-05-14 00:00:00')},
#    {'filename': '1129 (2025-04-16)RAW.csv',
#     'labID': '1129',
#     'date': Timestamp('2025-04-16 00:00:00')}],
#   '7019': [{'filename': '1130 (2024-09-24)RAW.csv',
#     'labID': '1130',
#     'date': Timestamp('2024-09-24 00:00:00')}],
#   '7020': [{'filename': '1131 (2024-10-08)RAW.csv',
#     'labID': '1131',
#     'date': Timestamp('2024-10-08 00:00:00')}],
#   '7021': [{'filename': '1132 (2024-10-02)RAW.csv',
#     'labID': '1132',
#     'date': Timestamp('2024-10-02 00:00:00')}],
#   '7022': [{'filename': '1133 (2024-10-01)RAW.csv',
#     'labID': '1133',
#     'date': Timestamp('2024-10-01 00:00:00')}],
#   '8005': [{'filename': '1134 (2024-10-30)RAW.csv',
#     'labID': '1134',
#     'date': Timestamp('2024-10-30 00:00:00')},
#    {'filename': '1134 (2025-01-15)RAW.csv',
#     'labID': '1134',
#     'date': Timestamp('2025-01-15 00:00:00')},
#    {'filename': '1134 (2025-05-22)RAW.csv',
#     'labID': '1134',
#     'date': Timestamp('2025-05-22 00:00:00')},
#    {'filename': '1134 (2025-06-26)RAW.csv',
#     'labID': '1134',
#     'date': Timestamp('2025-06-26 00:00:00')}],
#   '7024': [{'filename': '1136 (2024-10-11)RAW.csv',
#     'labID': '1136',
#     'date': Timestamp('2024-10-11 00:00:00')}],
#   '7025': [{'filename': '1137 (2024-10-11)RAW.csv',
#     'labID': '1137',
#     'date': Timestamp('2024-10-11 00:00:00')}],
#   '7026': [{'filename': '1138 (2024-10-24)RAW.csv',
#     'labID': '1138',
#     'date': Timestamp('2024-10-24 00:00:00')}],
#   '7027': [{'filename': '1139 (2024-11-08)RAW.csv',
#     'labID': '1139',
#     'date': Timestamp('2024-11-08 00:00:00')}],
#   '7028': [{'filename': '1140 (2024-10-28)RAW.csv',
#     'labID': '1140',
#     'date': Timestamp('2024-10-28 00:00:00')}],
#   '7029': [{'filename': '1141 (2024-11-05)RAW.csv',
#     'labID': '1141',
#     'date': Timestamp('2024-11-05 00:00:00')}],
#   '7030': [{'filename': '1142 (2024-10-24)RAW.csv',
#     'labID': '1142',
#     'date': Timestamp('2024-10-24 00:00:00')}],
#   '7032': [{'filename': '1144 (2024-11-12)RAW.csv',
#     'labID': '1144',
#     'date': Timestamp('2024-11-12 00:00:00')}],
#   '7033': [{'filename': '1145 (2024-11-06)RAW.csv',
#     'labID': '1145',
#     'date': Timestamp('2024-11-06 00:00:00')}],
#   '8008': [{'filename': '1146 (2024-11-04)RAW.csv',
#     'labID': '1146',
#     'date': Timestamp('2024-11-04 00:00:00')},
#    {'filename': '1146 (2025-01-09)RAW.csv',
#     'labID': '1146',
#     'date': Timestamp('2025-01-09 00:00:00')},
#    {'filename': '1146 (2025-03-19)RAW.csv',
#     'labID': '1146',
#     'date': Timestamp('2025-03-19 00:00:00')}],
#   '7034': [{'filename': '1147 (2024-11-14)RAW.csv',
#     'labID': '1147',
#     'date': Timestamp('2024-11-14 00:00:00')}],
#   '7035': [{'filename': '1148 (2024-11-04)RAW.csv',
#     'labID': '1148',
#     'date': Timestamp('2024-11-04 00:00:00')}],
#   '8011': [{'filename': '1151 (2025-02-20)RAW.csv',
#     'labID': '1151',
#     'date': Timestamp('2025-02-20 00:00:00')},
#    {'filename': '1151 (2024-12-06)RAW.csv',
#     'labID': '1151',
#     'date': Timestamp('2024-12-06 00:00:00')}],
#   '7031': [{'filename': '1155 (2024-12-18)RAW.csv',
#     'labID': '1155',
#     'date': Timestamp('2024-12-18 00:00:00')}],
#   '8012': [{'filename': '1158 (2025-05-09)RAW.csv',
#     'labID': '1158',
#     'date': Timestamp('2025-05-09 00:00:00')},
#    {'filename': '1158 (2025-01-09)RAW.csv',
#     'labID': '1158',
#     'date': Timestamp('2025-01-09 00:00:00')}],
#   '8014': [{'filename': '1160 (2025-01-15)RAW.csv',
#     'labID': '1160',
#     'date': Timestamp('2025-01-15 00:00:00')},
#    {'filename': '1160 (2025-05-03)RAW.csv',
#     'labID': '1160',
#     'date': Timestamp('2025-05-03 00:00:00')}],
#   '7037': [{'filename': '1161 (2025-01-18)RAW.csv',
#     'labID': '1161',
#     'date': Timestamp('2025-01-18 00:00:00')}],
#   '8015': [{'filename': '1162 (2025-01-29)RAW.csv',
#     'labID': '1162',
#     'date': Timestamp('2025-01-29 00:00:00')}],
#   '8016': [{'filename': '1163 (2025-02-19)RAW.csv',
#     'labID': '1163',
#     'date': Timestamp('2025-02-19 00:00:00')},
#    {'filename': '1163 (2025-04-07)RAW.csv',
#     'labID': '1163',
#     'date': Timestamp('2025-04-07 00:00:00')}],
#   '8017': [{'filename': '1165 (2025-04-09)RAW.csv',
#     'labID': '1165',
#     'date': Timestamp('2025-04-09 00:00:00')}],
#   '7039': [{'filename': '1166 (2025-01-21)RAW.csv',
#     'labID': '1166',
#     'date': Timestamp('2025-01-21 00:00:00')}],
#   '8018': [{'filename': '1167 (2025-01-22)RAW.csv',
#     'labID': '1167',
#     'date': Timestamp('2025-01-22 00:00:00')},
#    {'filename': '1167 (2025-01-21)RAW.csv',
#     'labID': '1167',
#     'date': Timestamp('2025-01-21 00:00:00')},
#    {'filename': '1167 (2025-05-21)RAW.csv',
#     'labID': '1167',
#     'date': Timestamp('2025-05-21 00:00:00')}],
#   '8019': [{'filename': '1168 (2025-01-28)RAW.csv',
#     'labID': '1168',
#     'date': Timestamp('2025-01-28 00:00:00')},
#    {'filename': '1168 (2025-04-23)RAW.csv',
#     'labID': '1168',
#     'date': Timestamp('2025-04-23 00:00:00')}],
#   '8020': [{'filename': '1169 (2025-04-09)RAW.csv',
#     'labID': '1169',
#     'date': Timestamp('2025-04-09 00:00:00')},
#    {'filename': '1169 (2025-01-30)RAW.csv',
#     'labID': '1169',
#     'date': Timestamp('2025-01-30 00:00:00')}],
#   '8021': [{'filename': '1170 (2025-01-29)RAW.csv',
#     'labID': '1170',
#     'date': Timestamp('2025-01-29 00:00:00')},
#    {'filename': '1170 (2025-05-24)RAW.csv',
#     'labID': '1170',
#     'date': Timestamp('2025-05-24 00:00:00')}],
#   '7040': [{'filename': '1171 (2025-02-08)RAW.csv',
#     'labID': '1171',
#     'date': Timestamp('2025-02-08 00:00:00')}],
#   '7041': [{'filename': '1172 (2025-01-28)RAW.csv',
#     'labID': '1172',
#     'date': Timestamp('2025-01-28 00:00:00')},
#    {'filename': '1172 (2025-05-29)RAW.csv',
#     'labID': '1172',
#     'date': Timestamp('2025-05-29 00:00:00')}],
#   '7042': [{'filename': '1173 (2025-03-01)RAW.csv',
#     'labID': '1173',
#     'date': Timestamp('2025-03-01 00:00:00')}],
#   '7043': [{'filename': '1174 (2025-01-28)RAW.csv',
#     'labID': '1174',
#     'date': Timestamp('2025-01-28 00:00:00')},
#    {'filename': '1174 (2025-01-27)RAW.csv',
#     'labID': '1174',
#     'date': Timestamp('2025-01-27 00:00:00')}],
#   '7047': [{'filename': '1178 (2025-02-12)RAW.csv',
#     'labID': '1178',
#     'date': Timestamp('2025-02-12 00:00:00')}],
#   '7048': [{'filename': '1179 (2025-03-11)RAW.csv',
#     'labID': '1179',
#     'date': Timestamp('2025-03-11 00:00:00')}],
#   '7049': [{'filename': '1180 (2025-02-18)RAW.csv',
#     'labID': '1180',
#     'date': Timestamp('2025-02-18 00:00:00')}],
#   '7050': [{'filename': '1181 (2025-02-21)RAW.csv',
#     'labID': '1181',
#     'date': Timestamp('2025-02-21 00:00:00')}],
#   '7052': [{'filename': '1183 (2025-02-13)RAW.csv',
#     'labID': '1183',
#     'date': Timestamp('2025-02-13 00:00:00')}],
#   '8023': [{'filename': '1185 (2025-04-10)RAW.csv',
#     'labID': '1185',
#     'date': Timestamp('2025-04-10 00:00:00')}],
#   '8024': [{'filename': '1186 (2025-03-08)RAW.csv',
#     'labID': '1186',
#     'date': Timestamp('2025-03-08 00:00:00')},
#    {'filename': '1186 (2025-05-30)RAW.csv',
#     'labID': '1186',
#     'date': Timestamp('2025-05-30 00:00:00')}],
#   '7054': [{'filename': '1187 (2025-02-11)RAW.csv',
#     'labID': '1187',
#     'date': Timestamp('2025-02-11 00:00:00')}],
#   '7056': [{'filename': '1190 (2025-02-22)RAW.csv',
#     'labID': '1190',
#     'date': Timestamp('2025-02-22 00:00:00')}],
#   '7057': [{'filename': '1191 (2025-02-15)RAW.csv',
#     'labID': '1191',
#     'date': Timestamp('2025-02-15 00:00:00')}],
#   '7058': [{'filename': '1192 (2025-02-21)RAW.csv',
#     'labID': '1192',
#     'date': Timestamp('2025-02-21 00:00:00')}],
#   '7059': [{'filename': '1193 (2025-02-25)RAW.csv',
#     'labID': '1193',
#     'date': Timestamp('2025-02-25 00:00:00')}],
#   '8026': [{'filename': '1194 (2025-02-04)RAW.csv',
#     'labID': '1194',
#     'date': Timestamp('2025-02-04 00:00:00')},
#    {'filename': '1194 (2025-05-23)RAW.csv',
#     'labID': '1194',
#     'date': Timestamp('2025-05-23 00:00:00')}],
#   '7061': [{'filename': '1196 (2025-02-15)RAW.csv',
#     'labID': '1196',
#     'date': Timestamp('2025-02-15 00:00:00')}],
#   '7063': [{'filename': '1197 (2025-02-25)RAW.csv',
#     'labID': '1197',
#     'date': Timestamp('2025-02-25 00:00:00')}],
#   '8030': [{'filename': '1200 (2025-05-10)RAW.csv',
#     'labID': '1200',
#     'date': Timestamp('2025-05-10 00:00:00')}],
#   '7064': [{'filename': '1202 (2025-03-01)RAW.csv',
#     'labID': '1202',
#     'date': Timestamp('2025-03-01 00:00:00')}],
#   '7067': [{'filename': '1205 (2025-02-21)RAW.csv',
#     'labID': '1205',
#     'date': Timestamp('2025-02-21 00:00:00')}],
#   '7068': [{'filename': '1206 (2025-02-27)RAW.csv',
#     'labID': '1206',
#     'date': Timestamp('2025-02-27 00:00:00')}],
#   '7069': [{'filename': '1207 (2025-03-01)RAW.csv',
#     'labID': '1207',
#     'date': Timestamp('2025-03-01 00:00:00')}],
#   '7072': [{'filename': '1210 (2025-03-01)RAW.csv',
#     'labID': '1210',
#     'date': Timestamp('2025-03-01 00:00:00')}],
#   '7073': [{'filename': '1211 (2025-03-01)RAW.csv',
#     'labID': '1211',
#     'date': Timestamp('2025-03-01 00:00:00')}],
#   '7075': [{'filename': '1213 (2025-03-04)RAW.csv',
#     'labID': '1213',
#     'date': Timestamp('2025-03-04 00:00:00')}],
#   '7076': [{'filename': '1214 (2025-03-11)RAW.csv',
#     'labID': '1214',
#     'date': Timestamp('2025-03-11 00:00:00')}],
#   '7077': [{'filename': '1215 (2025-03-14)RAW.csv',
#     'labID': '1215',
#     'date': Timestamp('2025-03-14 00:00:00')}],
#   '7078': [{'filename': '1216 (2025-03-08)RAW.csv',
#     'labID': '1216',
#     'date': Timestamp('2025-03-08 00:00:00')}],
#   '7079': [{'filename': '1217 (2025-03-13)RAW.csv',
#     'labID': '1217',
#     'date': Timestamp('2025-03-13 00:00:00')}],
#   '7080': [{'filename': '1218 (2025-03-07)RAW.csv',
#     'labID': '1218',
#     'date': Timestamp('2025-03-07 00:00:00')}],
#   '7082': [{'filename': '1220 (2025-03-19)RAW.csv',
#     'labID': '1220',
#     'date': Timestamp('2025-03-19 00:00:00')}],
#   '8032': [{'filename': '1221 (2025-05-22)RAW.csv',
#     'labID': '1221',
#     'date': Timestamp('2025-05-22 00:00:00')}],
#   '7083': [{'filename': '1222 (2025-03-06)RAW.csv',
#     'labID': '1222',
#     'date': Timestamp('2025-03-06 00:00:00')}],
#   '7084': [{'filename': '1223 (2025-03-29)RAW.csv',
#     'labID': '1223',
#     'date': Timestamp('2025-03-29 00:00:00')}],
#   '7085': [{'filename': '1224 (2025-03-18)RAW.csv',
#     'labID': '1224',
#     'date': Timestamp('2025-03-18 00:00:00')}],
#   '7086': [{'filename': '1225 (2025-03-06)RAW.csv',
#     'labID': '1225',
#     'date': Timestamp('2025-03-06 00:00:00')}],
#   '7087': [{'filename': '1226 (2025-03-06)RAW.csv',
#     'labID': '1226',
#     'date': Timestamp('2025-03-06 00:00:00')}],
#   '7088': [{'filename': '1227 (2025-04-03)RAW.csv',
#     'labID': '1227',
#     'date': Timestamp('2025-04-03 00:00:00')}],
#   '7089': [{'filename': '1228 (2025-03-20)RAW.csv',
#     'labID': '1228',
#     'date': Timestamp('2025-03-20 00:00:00')}],
#   '7093': [{'filename': '1232 (2025-03-12)RAW.csv',
#     'labID': '1232',
#     'date': Timestamp('2025-03-12 00:00:00')}],
#   '7094': [{'filename': '1233 (2025-03-27)RAW.csv',
#     'labID': '1233',
#     'date': Timestamp('2025-03-27 00:00:00')}],
#   '7065': [{'filename': '1234 (2025-03-20)RAW.csv',
#     'labID': '1234',
#     'date': Timestamp('2025-03-20 00:00:00')}],
#   '7096': [{'filename': '1236 (2025-03-29)RAW.csv',
#     'labID': '1236',
#     'date': Timestamp('2025-03-29 00:00:00')}],
#   '7098': [{'filename': '1239 (2025-04-05)RAW.csv',
#     'labID': '1239',
#     'date': Timestamp('2025-04-05 00:00:00')}],
#   '7099': [{'filename': '1240 (2025-03-08)RAW.csv',
#     'labID': '1240',
#     'date': Timestamp('2025-03-08 00:00:00')}],
#   '7102': [{'filename': '1242 (2025-03-28)RAW.csv',
#     'labID': '1242',
#     'date': Timestamp('2025-03-28 00:00:00')}],
#   '7045': [{'filename': '1243 (2025-03-20)RAW.csv',
#     'labID': '1243',
#     'date': Timestamp('2025-03-20 00:00:00')}],
#   '7103': [{'filename': '1244 (2025-04-03)RAW.csv',
#     'labID': '1244',
#     'date': Timestamp('2025-04-03 00:00:00')}],
#   '7104': [{'filename': '1245 (2025-04-03)RAW.csv',
#     'labID': '1245',
#     'date': Timestamp('2025-04-03 00:00:00')}],
#   '7105': [{'filename': '1246 (2025-03-14)RAW.csv',
#     'labID': '1246',
#     'date': Timestamp('2025-03-14 00:00:00')}],
#   '8035': [{'filename': '1249 (2025-03-19)RAW.csv',
#     'labID': '1249',
#     'date': Timestamp('2025-03-19 00:00:00')},
#    {'filename': '1249 (2025-05-31)RAW.csv',
#     'labID': '1249',
#     'date': Timestamp('2025-05-31 00:00:00')}],
#   '7091': [{'filename': '1250 (2025-03-27)RAW.csv',
#     'labID': '1250',
#     'date': Timestamp('2025-03-27 00:00:00')}],
#   '7070': [{'filename': '1251 (2025-04-05)RAW.csv',
#     'labID': '1251',
#     'date': Timestamp('2025-04-05 00:00:00')}],
#   '7106': [{'filename': '1252 (2025-03-28)RAW.csv',
#     'labID': '1252',
#     'date': Timestamp('2025-03-28 00:00:00')}],
#   '7107': [{'filename': '1254 (2025-04-12)RAW.csv',
#     'labID': '1254',
#     'date': Timestamp('2025-04-12 00:00:00')}],
#   '7108': [{'filename': '1255 (2025-03-14)RAW.csv',
#     'labID': '1255',
#     'date': Timestamp('2025-03-14 00:00:00')}],
#   '7110': [{'filename': '1257 (2025-04-04)RAW.csv',
#     'labID': '1257',
#     'date': Timestamp('2025-04-04 00:00:00')}],
#   '7092': [{'filename': '1260 (2025-03-28)RAW.csv',
#     'labID': '1260',
#     'date': Timestamp('2025-03-28 00:00:00')}],
#   '7090': [{'filename': '1261 (2025-04-11)RAW.csv',
#     'labID': '1261',
#     'date': Timestamp('2025-04-11 00:00:00')}],
#   '7113': [{'filename': '1262 (2025-04-04)RAW.csv',
#     'labID': '1262',
#     'date': Timestamp('2025-04-04 00:00:00')}],
#   '7114': [{'filename': '1263 (2025-03-29)RAW.csv',
#     'labID': '1263',
#     'date': Timestamp('2025-03-29 00:00:00')}],
#   '7097': [{'filename': '1264 (2025-04-05)RAW.csv',
#     'labID': '1264',
#     'date': Timestamp('2025-04-05 00:00:00')}],
#   '7115': [{'filename': '1265 (2025-04-02)RAW.csv',
#     'labID': '1265',
#     'date': Timestamp('2025-04-02 00:00:00')}],
#   '7116': [{'filename': '1266 (2025-04-03)RAW.csv',
#     'labID': '1266',
#     'date': Timestamp('2025-04-03 00:00:00')}],
#   '7117': [{'filename': '1267 (2025-03-22)RAW.csv',
#     'labID': '1267',
#     'date': Timestamp('2025-03-22 00:00:00')}],
#   '7118': [{'filename': '1268 (2025-04-08)RAW.csv',
#     'labID': '1268',
#     'date': Timestamp('2025-04-08 00:00:00')}],
#   '7120': [{'filename': '1270 (2025-04-12)RAW.csv',
#     'labID': '1270',
#     'date': Timestamp('2025-04-12 00:00:00')}],
#   '7122': [{'filename': '1272 (2025-04-05)RAW.csv',
#     'labID': '1272',
#     'date': Timestamp('2025-04-05 00:00:00')}],
#   '8036': [{'filename': '1273 (2025-03-25)RAW.csv',
#     'labID': '1273',
#     'date': Timestamp('2025-03-25 00:00:00')}],
#   '8037': [{'filename': '1276 (2025-04-04)RAW.csv',
#     'labID': '1276',
#     'date': Timestamp('2025-04-04 00:00:00')}],
#   '7124': [{'filename': '1290 (2025-04-10)RAW.csv',
#     'labID': '1290',
#     'date': Timestamp('2025-04-10 00:00:00')}],
#   '7125': [{'filename': '1291 (2025-04-10)RAW.csv',
#     'labID': '1291',
#     'date': Timestamp('2025-04-10 00:00:00')}],
#   '7128': [{'filename': '1298 (2025-04-18)RAW.csv',
#     'labID': '1298',
#     'date': Timestamp('2025-04-18 00:00:00')}],
#   '7129': [{'filename': '1299 (2025-04-19)RAW.csv',
#     'labID': '1299',
#     'date': Timestamp('2025-04-19 00:00:00')}],
#   '8038': [{'filename': '1302 (2025-04-26)RAW.csv',
#     'labID': '1302',
#     'date': Timestamp('2025-04-26 00:00:00')}],
#   '7133': [{'filename': '1304 (2025-04-29)RAW.csv',
#     'labID': '1304',
#     'date': Timestamp('2025-04-29 00:00:00')}],
#   '7134': [{'filename': '1311 (2025-05-01)RAW.csv',
#     'labID': '1311',
#     'date': Timestamp('2025-05-01 00:00:00')}],
#   '7136': [{'filename': '1313 (2025-06-03)RAW.csv',
#     'labID': '1313',
#     'date': Timestamp('2025-06-03 00:00:00')}],
#   '8039': [{'filename': '1314 (2025-05-20)RAW.csv',
#     'labID': '1314',
#     'date': Timestamp('2025-05-20 00:00:00')}],
#   '7137': [{'filename': '1315 (2025-05-05)RAW.csv',
#     'labID': '1315',
#     'date': Timestamp('2025-05-05 00:00:00')}],
#   '8040': [{'filename': '1317 (2025-05-20)RAW.csv',
#     'labID': '1317',
#     'date': Timestamp('2025-05-20 00:00:00')}],
#   '8042': [{'filename': '1320 (2025-05-20)RAW.csv',
#     'labID': '1320',
#     'date': Timestamp('2025-05-20 00:00:00')}],
#   '7138': [{'filename': '1321 (2025-05-17)RAW.csv',
#     'labID': '1321',
#     'date': Timestamp('2025-05-17 00:00:00')}],
#   '7139': [{'filename': '1322 (2025-05-10)RAW.csv',
#     'labID': '1322',
#     'date': Timestamp('2025-05-10 00:00:00')}],
#   '7140': [{'filename': '1323 (2025-05-10)RAW.csv',
#     'labID': '1323',
#     'date': Timestamp('2025-05-10 00:00:00')}],
#   '7141': [{'filename': '1324 (2025-05-17)RAW.csv',
#     'labID': '1324',
#     'date': Timestamp('2025-05-17 00:00:00')}],
#   '7142': [{'filename': '1325 (2025-05-21)RAW.csv',
#     'labID': '1325',
#     'date': Timestamp('2025-05-21 00:00:00')}],
#   '7145': [{'filename': '1327 (2025-05-10)RAW.csv',
#     'labID': '1327',
#     'date': Timestamp('2025-05-10 00:00:00')}],
#   '7147': [{'filename': '1328 (2025-06-24)RAW.csv',
#     'labID': '1328',
#     'date': Timestamp('2025-06-24 00:00:00')}],
#   '8046': [{'filename': '1330 (2025-05-28)RAW.csv',
#     'labID': '1330',
#     'date': Timestamp('2025-05-28 00:00:00')}],
#   '7150': [{'filename': '1332 (2025-05-24)RAW.csv',
#     'labID': '1332',
#     'date': Timestamp('2025-05-24 00:00:00')}],
#   '7151': [{'filename': '1333 (2025-05-13)RAW.csv',
#     'labID': '1333',
#     'date': Timestamp('2025-05-13 00:00:00')}],
#   '7152': [{'filename': '1334 (2025-05-24)RAW.csv',
#     'labID': '1334',
#     'date': Timestamp('2025-05-24 00:00:00')}],
#   '8047': [{'filename': '1335 (2025-05-14)RAW.csv',
#     'labID': '1335',
#     'date': Timestamp('2025-05-14 00:00:00')}],
#   '8048': [{'filename': '1336 (2025-06-06)RAW.csv',
#     'labID': '1336',
#     'date': Timestamp('2025-06-06 00:00:00')}],
#   '7153': [{'filename': '1337 (2025-05-17)RAW.csv',
#     'labID': '1337',
#     'date': Timestamp('2025-05-17 00:00:00')}],
#   '7155': [{'filename': '1340 (2025-06-03)RAW.csv',
#     'labID': '1340',
#     'date': Timestamp('2025-06-03 00:00:00')}],
#   '8050': [{'filename': '1341 (2025-05-21)RAW.csv',
#     'labID': '1341',
#     'date': Timestamp('2025-05-21 00:00:00')}],
#   '7156': [{'filename': '1342 (2025-05-24)RAW.csv',
#     'labID': '1342',
#     'date': Timestamp('2025-05-24 00:00:00')}],
#   '8051': [{'filename': '1343 (2025-06-20)RAW.csv',
#     'labID': '1343',
#     'date': Timestamp('2025-06-20 00:00:00')}],
#   '7157': [{'filename': '1344 (2025-05-16)RAW.csv',
#     'labID': '1344',
#     'date': Timestamp('2025-05-16 00:00:00')}],
#   '8052': [{'filename': '1345 (2025-05-28)RAW.csv',
#     'labID': '1345',
#     'date': Timestamp('2025-05-28 00:00:00')}],
#   '8053': [{'filename': '1346 (2025-06-04)RAW.csv',
#     'labID': '1346',
#     'date': Timestamp('2025-06-04 00:00:00')}],
#   '8054': [{'filename': '1347 (2025-05-30)RAW.csv',
#     'labID': '1347',
#     'date': Timestamp('2025-05-30 00:00:00')}],
#   '7158': [{'filename': '1348 (2025-06-05)RAW.csv',
#     'labID': '1348',
#     'date': Timestamp('2025-06-05 00:00:00')}],
#   '7159': [{'filename': '1349 (2025-06-05)RAW.csv',
#     'labID': '1349',
#     'date': Timestamp('2025-06-05 00:00:00')}],
#   '7160': [{'filename': '1350 (2025-06-04)RAW.csv',
#     'labID': '1350',
#     'date': Timestamp('2025-06-04 00:00:00')}],
#   '7164': [{'filename': '1354 (2025-06-12)RAW.csv',
#     'labID': '1354',
#     'date': Timestamp('2025-06-12 00:00:00')}],
#   '7165': [{'filename': '1355 (2025-06-12)RAW.csv',
#     'labID': '1355',
#     'date': Timestamp('2025-06-12 00:00:00')}],
#   '7161': [{'filename': '1356 (2025-06-10)RAW.csv',
#     'labID': '1356',
#     'date': Timestamp('2025-06-10 00:00:00')}],
#   '7167': [{'filename': '1358 (2025-06-21)RAW.csv',
#     'labID': '1358',
#     'date': Timestamp('2025-06-21 00:00:00')}],
#   '7168': [{'filename': '1359 (2025-06-20)RAW.csv',
#     'labID': '1359',
#     'date': Timestamp('2025-06-20 00:00:00')}],
#   '7170': [{'filename': '1361 (2025-06-10)RAW.csv',
#     'labID': '1361',
#     'date': Timestamp('2025-06-10 00:00:00')}],
#   '7172': [{'filename': '1363 (2025-06-18)RAW.csv',
#     'labID': '1363',
#     'date': Timestamp('2025-06-18 00:00:00')}],
#   '7174': [{'filename': '1365 (2025-06-28)RAW.csv',
#     'labID': '1365',
#     'date': Timestamp('2025-06-28 00:00:00')}],
#   '7175': [{'filename': '1366 (2025-07-02)RAW.csv',
#     'labID': '1366',
#     'date': Timestamp('2025-07-02 00:00:00')}],
#   '7178': [{'filename': '1369 (2025-06-26)RAW.csv',
#     'labID': '1369',
#     'date': Timestamp('2025-06-26 00:00:00')}],
#   '7180': [{'filename': '1372 (2025-07-02)RAW.csv',
#     'labID': '1372',
#     'date': Timestamp('2025-07-02 00:00:00')}],
#   '8056': [{'filename': '1373 (2025-07-03)RAW.csv',
#     'labID': '1373',
#     'date': Timestamp('2025-07-03 00:00:00')}]},
#  'duplicates': []}
